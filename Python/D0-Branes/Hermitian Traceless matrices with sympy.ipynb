# %%
import sympy as sp
from sympy import I

# %%
a1,b1,c1,d1,e1,f1,g1,h1,j1,k1,l1,m1,n1,o1,p1, a2, b2, c2, d2, e2,f2,g2,h2,j2,k2,l2,m2,n2,o2,p2 = sp.symbols("a1,b1,c1,d1,e1,f1,g1,h1,j1,k1,l1,m1,n1,o1,p1, a2, b2, c2, d2, e2,f2,g2,h2,j2,k2,l2,m2,n2,o2,p2")

# %%
A = sp.Matrix([[a1     , d1+I*e1, f1+I*g1, h1+I*j1],
               [d1-I*e1, b1     , k1+I*l1, m1+I*n1], 
               [f1-I*g1, k1-I*l1, c1     , o1+I*p1], 
               [h1-I*j1, m1-I*n1, o1-I*p1, -a1-b1-c1]])

# %%
B = sp.Matrix([[a2     , d2+I*e2, f2+I*g2, h2+I*j2],
               [d2-I*e2, b2     , k2+I*l2, m2+I*n2 ], 
               [f2-I*g2, k2-I*l2, c2     , o2+I*p2], 
               [h2-I*j2, m2-I*n2, o2-I*p2, -a2-b2-c2]])

# %%
C = B*(A*B-B*A)-(A*B-B*A)*B

# %%
C
# Out:
# Matrix([
# [                                                                                                                                                                                                                                                                                                                                                                                                       -(d2 - I*e2)*(a1*(d2 + I*e2) - a2*(d1 + I*e1) - b1*(d2 + I*e2) + b2*(d1 + I*e1) + (f1 + I*g1)*(k2 - I*l2) - (f2 + I*g2)*(k1 - I*l1) + (h1 + I*j1)*(m2 - I*n2) - (h2 + I*j2)*(m1 - I*n1)) + (d2 + I*e2)*(-a1*(d2 - I*e2) + a2*(d1 - I*e1) + b1*(d2 - I*e2) - b2*(d1 - I*e1) - (f1 - I*g1)*(k2 + I*l2) + (f2 - I*g2)*(k1 + I*l1) - (h1 - I*j1)*(m2 + I*n2) + (h2 - I*j2)*(m1 + I*n1)) - (f2 - I*g2)*(a1*(f2 + I*g2) - a2*(f1 + I*g1) - c1*(f2 + I*g2) + c2*(f1 + I*g1) + (d1 + I*e1)*(k2 + I*l2) - (d2 + I*e2)*(k1 + I*l1) + (h1 + I*j1)*(o2 - I*p2) - (h2 + I*j2)*(o1 - I*p1)) + (f2 + I*g2)*(-a1*(f2 - I*g2) + a2*(f1 - I*g1) + c1*(f2 - I*g2) - c2*(f1 - I*g1) - (d1 - I*e1)*(k2 - I*l2) + (d2 - I*e2)*(k1 - I*l1) - (h1 - I*j1)*(o2 + I*p2) + (h2 - I*j2)*(o1 + I*p1)) - (h2 - I*j2)*(a1*(h2 + I*j2) - a2*(h1 + I*j1) + (d1 + I*e1)*(m2 + I*n2) - (d2 + I*e2)*(m1 + I*n1) + (f1 + I*g1)*(o2 + I*p2) - (f2 + I*g2)*(o1 + I*p1) + (h1 + I*j1)*(-a2 - b2 - c2) - (h2 + I*j2)*(-a1 - b1 - c1)) + (h2 + I*j2)*(-a1*(h2 - I*j2) + a2*(h1 - I*j1) - (d1 - I*e1)*(m2 - I*n2) + (d2 - I*e2)*(m1 - I*n1) - (f1 - I*g1)*(o2 - I*p2) + (f2 - I*g2)*(o1 - I*p1) - (h1 - I*j1)*(-a2 - b2 - c2) + (h2 - I*j2)*(-a1 - b1 - c1)),                                                                     a2*(a1*(d2 + I*e2) - a2*(d1 + I*e1) - b1*(d2 + I*e2) + b2*(d1 + I*e1) + (f1 + I*g1)*(k2 - I*l2) - (f2 + I*g2)*(k1 - I*l1) + (h1 + I*j1)*(m2 - I*n2) - (h2 + I*j2)*(m1 - I*n1)) - b2*(a1*(d2 + I*e2) - a2*(d1 + I*e1) - b1*(d2 + I*e2) + b2*(d1 + I*e1) + (f1 + I*g1)*(k2 - I*l2) - (f2 + I*g2)*(k1 - I*l1) + (h1 + I*j1)*(m2 - I*n2) - (h2 + I*j2)*(m1 - I*n1)) - (d2 + I*e2)*(-(d1 - I*e1)*(d2 + I*e2) + (d1 + I*e1)*(d2 - I*e2) - (f1 - I*g1)*(f2 + I*g2) + (f1 + I*g1)*(f2 - I*g2) - (h1 - I*j1)*(h2 + I*j2) + (h1 + I*j1)*(h2 - I*j2)) + (d2 + I*e2)*((d1 - I*e1)*(d2 + I*e2) - (d1 + I*e1)*(d2 - I*e2) - (k1 - I*l1)*(k2 + I*l2) + (k1 + I*l1)*(k2 - I*l2) - (m1 - I*n1)*(m2 + I*n2) + (m1 + I*n1)*(m2 - I*n2)) + (f2 + I*g2)*(-b1*(k2 - I*l2) + b2*(k1 - I*l1) + c1*(k2 - I*l2) - c2*(k1 - I*l1) - (d1 + I*e1)*(f2 - I*g2) + (d2 + I*e2)*(f1 - I*g1) - (m1 - I*n1)*(o2 + I*p2) + (m2 - I*n2)*(o1 + I*p1)) + (h2 + I*j2)*(-b1*(m2 - I*n2) + b2*(m1 - I*n1) - (d1 + I*e1)*(h2 - I*j2) + (d2 + I*e2)*(h1 - I*j1) - (k1 - I*l1)*(o2 - I*p2) + (k2 - I*l2)*(o1 - I*p1) - (m1 - I*n1)*(-a2 - b2 - c2) + (m2 - I*n2)*(-a1 - b1 - c1)) - (k2 - I*l2)*(a1*(f2 + I*g2) - a2*(f1 + I*g1) - c1*(f2 + I*g2) + c2*(f1 + I*g1) + (d1 + I*e1)*(k2 + I*l2) - (d2 + I*e2)*(k1 + I*l1) + (h1 + I*j1)*(o2 - I*p2) - (h2 + I*j2)*(o1 - I*p1)) - (m2 - I*n2)*(a1*(h2 + I*j2) - a2*(h1 + I*j1) + (d1 + I*e1)*(m2 + I*n2) - (d2 + I*e2)*(m1 + I*n1) + (f1 + I*g1)*(o2 + I*p2) - (f2 + I*g2)*(o1 + I*p1) + (h1 + I*j1)*(-a2 - b2 - c2) - (h2 + I*j2)*(-a1 - b1 - c1)),                                                                     a2*(a1*(f2 + I*g2) - a2*(f1 + I*g1) - c1*(f2 + I*g2) + c2*(f1 + I*g1) + (d1 + I*e1)*(k2 + I*l2) - (d2 + I*e2)*(k1 + I*l1) + (h1 + I*j1)*(o2 - I*p2) - (h2 + I*j2)*(o1 - I*p1)) - c2*(a1*(f2 + I*g2) - a2*(f1 + I*g1) - c1*(f2 + I*g2) + c2*(f1 + I*g1) + (d1 + I*e1)*(k2 + I*l2) - (d2 + I*e2)*(k1 + I*l1) + (h1 + I*j1)*(o2 - I*p2) - (h2 + I*j2)*(o1 - I*p1)) + (d2 + I*e2)*(b1*(k2 + I*l2) - b2*(k1 + I*l1) - c1*(k2 + I*l2) + c2*(k1 + I*l1) + (d1 - I*e1)*(f2 + I*g2) - (d2 - I*e2)*(f1 + I*g1) + (m1 + I*n1)*(o2 - I*p2) - (m2 + I*n2)*(o1 - I*p1)) - (f2 + I*g2)*(-(d1 - I*e1)*(d2 + I*e2) + (d1 + I*e1)*(d2 - I*e2) - (f1 - I*g1)*(f2 + I*g2) + (f1 + I*g1)*(f2 - I*g2) - (h1 - I*j1)*(h2 + I*j2) + (h1 + I*j1)*(h2 - I*j2)) + (f2 + I*g2)*((f1 - I*g1)*(f2 + I*g2) - (f1 + I*g1)*(f2 - I*g2) + (k1 - I*l1)*(k2 + I*l2) - (k1 + I ...
# [                                                                   -a2*(-a1*(d2 - I*e2) + a2*(d1 - I*e1) + b1*(d2 - I*e2) - b2*(d1 - I*e1) - (f1 - I*g1)*(k2 + I*l2) + (f2 - I*g2)*(k1 + I*l1) - (h1 - I*j1)*(m2 + I*n2) + (h2 - I*j2)*(m1 + I*n1)) + b2*(-a1*(d2 - I*e2) + a2*(d1 - I*e1) + b1*(d2 - I*e2) - b2*(d1 - I*e1) - (f1 - I*g1)*(k2 + I*l2) + (f2 - I*g2)*(k1 + I*l1) - (h1 - I*j1)*(m2 + I*n2) + (h2 - I*j2)*(m1 + I*n1)) + (d2 - I*e2)*(-(d1 - I*e1)*(d2 + I*e2) + (d1 + I*e1)*(d2 - I*e2) - (f1 - I*g1)*(f2 + I*g2) + (f1 + I*g1)*(f2 - I*g2) - (h1 - I*j1)*(h2 + I*j2) + (h1 + I*j1)*(h2 - I*j2)) - (d2 - I*e2)*((d1 - I*e1)*(d2 + I*e2) - (d1 + I*e1)*(d2 - I*e2) - (k1 - I*l1)*(k2 + I*l2) + (k1 + I*l1)*(k2 - I*l2) - (m1 - I*n1)*(m2 + I*n2) + (m1 + I*n1)*(m2 - I*n2)) - (f2 - I*g2)*(b1*(k2 + I*l2) - b2*(k1 + I*l1) - c1*(k2 + I*l2) + c2*(k1 + I*l1) + (d1 - I*e1)*(f2 + I*g2) - (d2 - I*e2)*(f1 + I*g1) + (m1 + I*n1)*(o2 - I*p2) - (m2 + I*n2)*(o1 - I*p1)) - (h2 - I*j2)*(b1*(m2 + I*n2) - b2*(m1 + I*n1) + (d1 - I*e1)*(h2 + I*j2) - (d2 - I*e2)*(h1 + I*j1) + (k1 + I*l1)*(o2 + I*p2) - (k2 + I*l2)*(o1 + I*p1) + (m1 + I*n1)*(-a2 - b2 - c2) - (m2 + I*n2)*(-a1 - b1 - c1)) + (k2 + I*l2)*(-a1*(f2 - I*g2) + a2*(f1 - I*g1) + c1*(f2 - I*g2) - c2*(f1 - I*g1) - (d1 - I*e1)*(k2 - I*l2) + (d2 - I*e2)*(k1 - I*l1) - (h1 - I*j1)*(o2 + I*p2) + (h2 - I*j2)*(o1 + I*p1)) + (m2 + I*n2)*(-a1*(h2 - I*j2) + a2*(h1 - I*j1) - (d1 - I*e1)*(m2 - I*n2) + (d2 - I*e2)*(m1 - I*n1) - (f1 - I*g1)*(o2 - I*p2) + (f2 - I*g2)*(o1 - I*p1) - (h1 - I*j1)*(-a2 - b2 - c2) + (h2 - I*j2)*(-a1 - b1 - c1)),                                                                                                                                                                                                                                                                                                                                                                                                       (d2 - I*e2)*(a1*(d2 + I*e2) - a2*(d1 + I*e1) - b1*(d2 + I*e2) + b2*(d1 + I*e1) + (f1 + I*g1)*(k2 - I*l2) - (f2 + I*g2)*(k1 - I*l1) + (h1 + I*j1)*(m2 - I*n2) - (h2 + I*j2)*(m1 - I*n1)) - (d2 + I*e2)*(-a1*(d2 - I*e2) + a2*(d1 - I*e1) + b1*(d2 - I*e2) - b2*(d1 - I*e1) - (f1 - I*g1)*(k2 + I*l2) + (f2 - I*g2)*(k1 + I*l1) - (h1 - I*j1)*(m2 + I*n2) + (h2 - I*j2)*(m1 + I*n1)) - (k2 - I*l2)*(b1*(k2 + I*l2) - b2*(k1 + I*l1) - c1*(k2 + I*l2) + c2*(k1 + I*l1) + (d1 - I*e1)*(f2 + I*g2) - (d2 - I*e2)*(f1 + I*g1) + (m1 + I*n1)*(o2 - I*p2) - (m2 + I*n2)*(o1 - I*p1)) + (k2 + I*l2)*(-b1*(k2 - I*l2) + b2*(k1 - I*l1) + c1*(k2 - I*l2) - c2*(k1 - I*l1) - (d1 + I*e1)*(f2 - I*g2) + (d2 + I*e2)*(f1 - I*g1) - (m1 - I*n1)*(o2 + I*p2) + (m2 - I*n2)*(o1 + I*p1)) - (m2 - I*n2)*(b1*(m2 + I*n2) - b2*(m1 + I*n1) + (d1 - I*e1)*(h2 + I*j2) - (d2 - I*e2)*(h1 + I*j1) + (k1 + I*l1)*(o2 + I*p2) - (k2 + I*l2)*(o1 + I*p1) + (m1 + I*n1)*(-a2 - b2 - c2) - (m2 + I*n2)*(-a1 - b1 - c1)) + (m2 + I*n2)*(-b1*(m2 - I*n2) + b2*(m1 - I*n1) - (d1 + I*e1)*(h2 - I*j2) + (d2 + I*e2)*(h1 - I*j1) - (k1 - I*l1)*(o2 - I*p2) + (k2 - I*l2)*(o1 - I*p1) - (m1 - I*n1)*(-a2 - b2 - c2) + (m2 - I*n2)*(-a1 - b1 - c1)),                                                                     b2*(b1*(k2 + I*l2) - b2*(k1 + I*l1) - c1*(k2 + I*l2) + c2*(k1 + I*l1) + (d1 - I*e1)*(f2 + I*g2) - (d2 - I*e2)*(f1 + I*g1) + (m1 + I*n1)*(o2 - I*p2) - (m2 + I*n2)*(o1 - I*p1)) - c2*(b1*(k2 + I*l2) - b2*(k1 + I*l1) - c1*(k2 + I*l2) + c2*(k1 + I*l1) + (d1 - I*e1)*(f2 + I*g2) - (d2 - I*e2)*(f1 + I*g1) + (m1 + I*n1)*(o2 - I*p2) - (m2 + I*n2)*(o1 - I*p1)) + (d2 - I*e2)*(a1*(f2 + I*g2) - a2*(f1 + I*g1) - c1*(f2 + I*g2) + c2*(f1 + I*g1) + (d1 + I*e1)*(k2 + I*l2) - (d2 + I*e2)*(k1 + I*l1) + (h1 + I*j1)*(o2 - I*p2) - (h2 + I*j2)*(o1 - I*p1)) - (f2 + I*g2)*(-a1*(d2 - I*e2) + a2*(d1 - I*e1) + b1*(d2 - I*e2) - b2*(d1 - I*e1) - (f1 - I*g1)*(k2 + I*l2) + (f2 - I*g2)*(k1 + I*l1) - (h1 - I*j1)*(m2 + I*n2) + (h2 - I*j2)*(m1 + I*n1)) - (k2 + I*l2)*((d1 - I*e1)*(d2 + I*e2) - (d1 + I*e1)*(d2 - I*e2) - (k1 - I*l1)*(k2 + ...
# [                                                                  -a2*(-a1*(f2 - I*g2) + a2*(f1 - I*g1) + c1*(f2 - I*g2) - c2*(f1 - I*g1) - (d1 - I*e1)*(k2 - I*l2) + (d2 - I*e2)*(k1 - I*l1) - (h1 - I*j1)*(o2 + I*p2) + (h2 - I*j2)*(o1 + I*p1)) + c2*(-a1*(f2 - I*g2) + a2*(f1 - I*g1) + c1*(f2 - I*g2) - c2*(f1 - I*g1) - (d1 - I*e1)*(k2 - I*l2) + (d2 - I*e2)*(k1 - I*l1) - (h1 - I*j1)*(o2 + I*p2) + (h2 - I*j2)*(o1 + I*p1)) - (d2 - I*e2)*(-b1*(k2 - I*l2) + b2*(k1 - I*l1) + c1*(k2 - I*l2) - c2*(k1 - I*l1) - (d1 + I*e1)*(f2 - I*g2) + (d2 + I*e2)*(f1 - I*g1) - (m1 - I*n1)*(o2 + I*p2) + (m2 - I*n2)*(o1 + I*p1)) + (f2 - I*g2)*(-(d1 - I*e1)*(d2 + I*e2) + (d1 + I*e1)*(d2 - I*e2) - (f1 - I*g1)*(f2 + I*g2) + (f1 + I*g1)*(f2 - I*g2) - (h1 - I*j1)*(h2 + I*j2) + (h1 + I*j1)*(h2 - I*j2)) - (f2 - I*g2)*((f1 - I*g1)*(f2 + I*g2) - (f1 + I*g1)*(f2 - I*g2) + (k1 - I*l1)*(k2 + I*l2) - (k1 + I*l1)*(k2 - I*l2) - (o1 - I*p1)*(o2 + I*p2) + (o1 + I*p1)*(o2 - I*p2)) - (h2 - I*j2)*(c1*(o2 + I*p2) - c2*(o1 + I*p1) + (f1 - I*g1)*(h2 + I*j2) - (f2 - I*g2)*(h1 + I*j1) + (k1 - I*l1)*(m2 + I*n2) - (k2 - I*l2)*(m1 + I*n1) + (o1 + I*p1)*(-a2 - b2 - c2) - (o2 + I*p2)*(-a1 - b1 - c1)) + (k2 - I*l2)*(-a1*(d2 - I*e2) + a2*(d1 - I*e1) + b1*(d2 - I*e2) - b2*(d1 - I*e1) - (f1 - I*g1)*(k2 + I*l2) + (f2 - I*g2)*(k1 + I*l1) - (h1 - I*j1)*(m2 + I*n2) + (h2 - I*j2)*(m1 + I*n1)) + (o2 + I*p2)*(-a1*(h2 - I*j2) + a2*(h1 - I*j1) - (d1 - I*e1)*(m2 - I*n2) + (d2 - I*e2)*(m1 - I*n1) - (f1 - I*g1)*(o2 - I*p2) + (f2 - I*g2)*(o1 - I*p1) - (h1 - I*j1)*(-a2 - b2 - c2) + (h2 - I*j2)*(-a1 - b1 - c1)),                                                                   -b2*(-b1*(k2 - I*l2) + b2*(k1 - I*l1) + c1*(k2 - I*l2) - c2*(k1 - I*l1) - (d1 + I*e1)*(f2 - I*g2) + (d2 + I*e2)*(f1 - I*g1) - (m1 - I*n1)*(o2 + I*p2) + (m2 - I*n2)*(o1 + I*p1)) + c2*(-b1*(k2 - I*l2) + b2*(k1 - I*l1) + c1*(k2 - I*l2) - c2*(k1 - I*l1) - (d1 + I*e1)*(f2 - I*g2) + (d2 + I*e2)*(f1 - I*g1) - (m1 - I*n1)*(o2 + I*p2) + (m2 - I*n2)*(o1 + I*p1)) - (d2 + I*e2)*(-a1*(f2 - I*g2) + a2*(f1 - I*g1) + c1*(f2 - I*g2) - c2*(f1 - I*g1) - (d1 - I*e1)*(k2 - I*l2) + (d2 - I*e2)*(k1 - I*l1) - (h1 - I*j1)*(o2 + I*p2) + (h2 - I*j2)*(o1 + I*p1)) + (f2 - I*g2)*(a1*(d2 + I*e2) - a2*(d1 + I*e1) - b1*(d2 + I*e2) + b2*(d1 + I*e1) + (f1 + I*g1)*(k2 - I*l2) - (f2 + I*g2)*(k1 - I*l1) + (h1 + I*j1)*(m2 - I*n2) - (h2 + I*j2)*(m1 - I*n1)) + (k2 - I*l2)*((d1 - I*e1)*(d2 + I*e2) - (d1 + I*e1)*(d2 - I*e2) - (k1 - I*l1)*(k2 + I*l2) + (k1 + I*l1)*(k2 - I*l2) - (m1 - I*n1)*(m2 + I*n2) + (m1 + I*n1)*(m2 - I*n2)) - (k2 - I*l2)*((f1 - I*g1)*(f2 + I*g2) - (f1 + I*g1)*(f2 - I*g2) + (k1 - I*l1)*(k2 + I*l2) - (k1 + I*l1)*(k2 - I*l2) - (o1 - I*p1)*(o2 + I*p2) + (o1 + I*p1)*(o2 - I*p2)) - (m2 - I*n2)*(c1*(o2 + I*p2) - c2*(o1 + I*p1) + (f1 - I*g1)*(h2 + I*j2) - (f2 - I*g2)*(h1 + I*j1) + (k1 - I*l1)*(m2 + I*n2) - (k2 - I*l2)*(m1 + I*n1) + (o1 + I*p1)*(-a2 - b2 - c2) - (o2 + I*p2)*(-a1 - b1 - c1)) + (o2 + I*p2)*(-b1*(m2 - I*n2) + b2*(m1 - I*n1) - (d1 + I*e1)*(h2 - I*j2) + (d2 + I*e2)*(h1 - I*j1) - (k1 - I*l1)*(o2 - I*p2) + (k2 - I*l2)*(o1 - I*p1) - (m1 - I*n1)*(-a2 - b2 - c2) + (m2 - I*n2)*(-a1 - b1 - c1)),                                                                                                                                                                                                                                                                                                                                                                                                      (f2 - I*g2)*(a1*(f2 + I*g2) - a2*(f1 + I*g1) - c1*(f2 + I*g2) + c2*(f1 + I*g1) + (d1 + I*e1)*(k2 + I*l2) - (d2 + I*e2)*(k1 + I*l1) + (h1 + I*j1)*(o2 - I*p2) - (h2 + I*j2)*(o1 - I*p1)) - (f2 + I*g2)*(-a1*(f2 - I*g2) + a2*(f1 - I*g1) + c1*(f2 - I*g2) - c2*(f1 - I*g1) - (d1 - I*e1)*(k2 - I*l2) + (d2 - I*e2)*(k1 - I*l1) - (h1 - I*j1)*(o2 + I*p2) + (h2 - I*j2)*(o1 + I*p1)) + (k2 - I*l2)*(b1*(k2 + I*l2) - b2*(k1 + I*l1) - c1*(k2 + I*l2) + c2*(k1 + I*l1) + (d1 - I*e1)*(f2 + I*g2) - (d2 - I* ...
# [-a2*(-a1*(h2 - I*j2) + a2*(h1 - I*j1) - (d1 - I*e1)*(m2 - I*n2) + (d2 - I*e2)*(m1 - I*n1) - (f1 - I*g1)*(o2 - I*p2) + (f2 - I*g2)*(o1 - I*p1) - (h1 - I*j1)*(-a2 - b2 - c2) + (h2 - I*j2)*(-a1 - b1 - c1)) - (d2 - I*e2)*(-b1*(m2 - I*n2) + b2*(m1 - I*n1) - (d1 + I*e1)*(h2 - I*j2) + (d2 + I*e2)*(h1 - I*j1) - (k1 - I*l1)*(o2 - I*p2) + (k2 - I*l2)*(o1 - I*p1) - (m1 - I*n1)*(-a2 - b2 - c2) + (m2 - I*n2)*(-a1 - b1 - c1)) - (f2 - I*g2)*(-c1*(o2 - I*p2) + c2*(o1 - I*p1) - (f1 + I*g1)*(h2 - I*j2) + (f2 + I*g2)*(h1 - I*j1) - (k1 + I*l1)*(m2 - I*n2) + (k2 + I*l2)*(m1 - I*n1) - (o1 - I*p1)*(-a2 - b2 - c2) + (o2 - I*p2)*(-a1 - b1 - c1)) + (h2 - I*j2)*(-(d1 - I*e1)*(d2 + I*e2) + (d1 + I*e1)*(d2 - I*e2) - (f1 - I*g1)*(f2 + I*g2) + (f1 + I*g1)*(f2 - I*g2) - (h1 - I*j1)*(h2 + I*j2) + (h1 + I*j1)*(h2 - I*j2)) - (h2 - I*j2)*((h1 - I*j1)*(h2 + I*j2) - (h1 + I*j1)*(h2 - I*j2) + (m1 - I*n1)*(m2 + I*n2) - (m1 + I*n1)*(m2 - I*n2) + (o1 - I*p1)*(o2 + I*p2) - (o1 + I*p1)*(o2 - I*p2)) + (m2 - I*n2)*(-a1*(d2 - I*e2) + a2*(d1 - I*e1) + b1*(d2 - I*e2) - b2*(d1 - I*e1) - (f1 - I*g1)*(k2 + I*l2) + (f2 - I*g2)*(k1 + I*l1) - (h1 - I*j1)*(m2 + I*n2) + (h2 - I*j2)*(m1 + I*n1)) + (o2 - I*p2)*(-a1*(f2 - I*g2) + a2*(f1 - I*g1) + c1*(f2 - I*g2) - c2*(f1 - I*g1) - (d1 - I*e1)*(k2 - I*l2) + (d2 - I*e2)*(k1 - I*l1) - (h1 - I*j1)*(o2 + I*p2) + (h2 - I*j2)*(o1 + I*p1)) + (-a2 - b2 - c2)*(-a1*(h2 - I*j2) + a2*(h1 - I*j1) - (d1 - I*e1)*(m2 - I*n2) + (d2 - I*e2)*(m1 - I*n1) - (f1 - I*g1)*(o2 - I*p2) + (f2 - I*g2)*(o1 - I*p1) - (h1 - I*j1)*(-a2 - b2 - c2) + (h2 - I*j2)*(-a1 - b1 - c1)), -b2*(-b1*(m2 - I*n2) + b2*(m1 - I*n1) - (d1 + I*e1)*(h2 - I*j2) + (d2 + I*e2)*(h1 - I*j1) - (k1 - I*l1)*(o2 - I*p2) + (k2 - I*l2)*(o1 - I*p1) - (m1 - I*n1)*(-a2 - b2 - c2) + (m2 - I*n2)*(-a1 - b1 - c1)) - (d2 + I*e2)*(-a1*(h2 - I*j2) + a2*(h1 - I*j1) - (d1 - I*e1)*(m2 - I*n2) + (d2 - I*e2)*(m1 - I*n1) - (f1 - I*g1)*(o2 - I*p2) + (f2 - I*g2)*(o1 - I*p1) - (h1 - I*j1)*(-a2 - b2 - c2) + (h2 - I*j2)*(-a1 - b1 - c1)) + (h2 - I*j2)*(a1*(d2 + I*e2) - a2*(d1 + I*e1) - b1*(d2 + I*e2) + b2*(d1 + I*e1) + (f1 + I*g1)*(k2 - I*l2) - (f2 + I*g2)*(k1 - I*l1) + (h1 + I*j1)*(m2 - I*n2) - (h2 + I*j2)*(m1 - I*n1)) - (k2 - I*l2)*(-c1*(o2 - I*p2) + c2*(o1 - I*p1) - (f1 + I*g1)*(h2 - I*j2) + (f2 + I*g2)*(h1 - I*j1) - (k1 + I*l1)*(m2 - I*n2) + (k2 + I*l2)*(m1 - I*n1) - (o1 - I*p1)*(-a2 - b2 - c2) + (o2 - I*p2)*(-a1 - b1 - c1)) + (m2 - I*n2)*((d1 - I*e1)*(d2 + I*e2) - (d1 + I*e1)*(d2 - I*e2) - (k1 - I*l1)*(k2 + I*l2) + (k1 + I*l1)*(k2 - I*l2) - (m1 - I*n1)*(m2 + I*n2) + (m1 + I*n1)*(m2 - I*n2)) - (m2 - I*n2)*((h1 - I*j1)*(h2 + I*j2) - (h1 + I*j1)*(h2 - I*j2) + (m1 - I*n1)*(m2 + I*n2) - (m1 + I*n1)*(m2 - I*n2) + (o1 - I*p1)*(o2 + I*p2) - (o1 + I*p1)*(o2 - I*p2)) + (o2 - I*p2)*(-b1*(k2 - I*l2) + b2*(k1 - I*l1) + c1*(k2 - I*l2) - c2*(k1 - I*l1) - (d1 + I*e1)*(f2 - I*g2) + (d2 + I*e2)*(f1 - I*g1) - (m1 - I*n1)*(o2 + I*p2) + (m2 - I*n2)*(o1 + I*p1)) + (-a2 - b2 - c2)*(-b1*(m2 - I*n2) + b2*(m1 - I*n1) - (d1 + I*e1)*(h2 - I*j2) + (d2 + I*e2)*(h1 - I*j1) - (k1 - I*l1)*(o2 - I*p2) + (k2 - I*l2)*(o1 - I*p1) - (m1 - I*n1)*(-a2 - b2 - c2) + (m2 - I*n2)*(-a1 - b1 - c1)), -c2*(-c1*(o2 - I*p2) + c2*(o1 - I*p1) - (f1 + I*g1)*(h2 - I*j2) + (f2 + I*g2)*(h1 - I*j1) - (k1 + I*l1)*(m2 - I*n2) + (k2 + I*l2)*(m1 - I*n1) - (o1 - I*p1)*(-a2 - b2 - c2) + (o2 - I*p2)*(-a1 - b1 - c1)) - (f2 + I*g2)*(-a1*(h2 - I*j2) + a2*(h1 - I*j1) - (d1 - I*e1)*(m2 - I*n2) + (d2 - I*e2)*(m1 - I*n1) - (f1 - I*g1)*(o2 - I*p2) + (f2 - I*g2)*(o1 - I*p1) - (h1 - I*j1)*(-a2 - b2 - c2) + (h2 - I*j2)*(-a1 - b1 - c1)) + (h2 - I*j2)*(a1*(f2 + I*g2) - a2*(f1 + I*g1) - c1*(f2 + I*g2) + c2*(f1 + I*g1) + (d1 + I*e1)*(k2 + I*l2) - (d2 + I*e2)*(k1 + I*l1) + (h1 + I*j1)*(o2 - I*p2) - (h2 + I*j2)*(o1 - I*p1)) - (k2 + I*l2)*(-b1*(m2 - I*n2) + b2*(m1 - I*n1) - (d1 + I*e1)*(h2 - I*j2) + (d2 + I*e2)*(h1 - I*j1) - (k1 - I*l1)*(o2 - I*p2) + (k2 - I*l2)*(o1 - I*p1) - (m1 - I*n1)*(-a2 - b2 - c2) + (m2 - I*n2)*(-a1 - b1 - c1)) + (m2 - I*n2)*(b1*(k2 + I*l2) - b2*(k1 + I*l1) - c1*(k2 + I*l2 ...

# %%
print(C[0,0].expand())
# Out:
# -2*a1*d2**2 - 2*a1*e2**2 - 2*a1*f2**2 - 2*a1*g2**2 - 4*a1*h2**2 - 4*a1*j2**2 + 2*a2*d1*d2 + 2*a2*e1*e2 + 2*a2*f1*f2 + 2*a2*g1*g2 + 4*a2*h1*h2 + 4*a2*j1*j2 + 2*b1*d2**2 + 2*b1*e2**2 - 2*b1*h2**2 - 2*b1*j2**2 - 2*b2*d1*d2 - 2*b2*e1*e2 + 2*b2*h1*h2 + 2*b2*j1*j2 + 2*c1*f2**2 + 2*c1*g2**2 - 2*c1*h2**2 - 2*c1*j2**2 - 2*c2*f1*f2 - 2*c2*g1*g2 + 2*c2*h1*h2 + 2*c2*j1*j2 - 2*d1*f2*k2 - 2*d1*g2*l2 - 2*d1*h2*m2 - 2*d1*j2*n2 - 2*d2*f1*k2 + 4*d2*f2*k1 - 2*d2*g1*l2 + 4*d2*g2*l1 - 2*d2*h1*m2 + 4*d2*h2*m1 - 2*d2*j1*n2 + 4*d2*j2*n1 + 2*e1*f2*l2 - 2*e1*g2*k2 + 2*e1*h2*n2 - 2*e1*j2*m2 + 2*e2*f1*l2 - 4*e2*f2*l1 - 2*e2*g1*k2 + 4*e2*g2*k1 + 2*e2*h1*n2 - 4*e2*h2*n1 - 2*e2*j1*m2 + 4*e2*j2*m1 - 2*f1*h2*o2 - 2*f1*j2*p2 - 2*f2*h1*o2 + 4*f2*h2*o1 - 2*f2*j1*p2 + 4*f2*j2*p1 + 2*g1*h2*p2 - 2*g1*j2*o2 + 2*g2*h1*p2 - 4*g2*h2*p1 - 2*g2*j1*o2 + 4*g2*j2*o1

# %%
row = 2
col = 3
print(((C[row,col].expand()+C[col,row].expand())/(2)).expand())
# Out:
# a1*a2*o2 + a1*b2*o2 + 2*a1*c2*o2 + 3*a1*f2*h2 + 3*a1*g2*j2 + a1*k2*m2 + a1*l2*n2 - a2**2*o1 + a2*b1*o2 - 2*a2*b2*o1 + 2*a2*c1*o2 - 4*a2*c2*o1 - 3*a2*f2*h1 - 3*a2*g2*j1 + a2*k1*m2 - 2*a2*k2*m1 + a2*l1*n2 - 2*a2*l2*n1 + b1*b2*o2 + 2*b1*c2*o2 + b1*f2*h2 + b1*g2*j2 + 3*b1*k2*m2 + 3*b1*l2*n2 - b2**2*o1 + 2*b2*c1*o2 - 4*b2*c2*o1 + b2*f1*h2 - 2*b2*f2*h1 + b2*g1*j2 - 2*b2*g2*j1 - 3*b2*k2*m1 - 3*b2*l2*n1 + 4*c1*c2*o2 - 4*c2**2*o1 + 3*c2*f1*h2 - 3*c2*f2*h1 + 3*c2*g1*j2 - 3*c2*g2*j1 + 3*c2*k1*m2 - 3*c2*k2*m1 + 3*c2*l1*n2 - 3*c2*l2*n1 + 2*d1*f2*m2 + 2*d1*g2*n2 + 2*d1*h2*k2 + 2*d1*j2*l2 - d2*f1*m2 - d2*f2*m1 - d2*g1*n2 - d2*g2*n1 - d2*h1*k2 - d2*h2*k1 - d2*j1*l2 - d2*j2*l1 - 2*e1*f2*n2 + 2*e1*g2*m2 - 2*e1*h2*l2 + 2*e1*j2*k2 + e2*f1*n2 + e2*f2*n1 - e2*g1*m2 - e2*g2*m1 + e2*h1*l2 + e2*h2*l1 - e2*j1*k2 - e2*j2*k1 + f1*f2*o2 + 3*f1*g2*p2 - f2**2*o1 - 3*f2*g1*p2 + g1*g2*o2 - g2**2*o1 + h1*h2*o2 - 3*h1*j2*p2 - h2**2*o1 + 3*h2*j1*p2 + j1*j2*o2 - j2**2*o1 + k1*k2*o2 + 3*k1*l2*p2 - k2**2*o1 - 3*k2*l1*p2 + l1*l2*o2 - l2**2*o1 + m1*m2*o2 - 3*m1*n2*p2 - m2**2*o1 + 3*m2*n1*p2 + n1*n2*o2 - n2**2*o1 - 4*o1*p2**2 + 4*o2*p1*p2

# %%
print(((C[row,col].expand()-C[col,row].expand())/(I*2)).expand())
# Out:
# a1*a2*p2 + a1*b2*p2 + 2*a1*c2*p2 + 3*a1*f2*j2 - 3*a1*g2*h2 + a1*k2*n2 - a1*l2*m2 - a2**2*p1 + a2*b1*p2 - 2*a2*b2*p1 + 2*a2*c1*p2 - 4*a2*c2*p1 - 3*a2*f2*j1 + 3*a2*g2*h1 + a2*k1*n2 - 2*a2*k2*n1 - a2*l1*m2 + 2*a2*l2*m1 + b1*b2*p2 + 2*b1*c2*p2 + b1*f2*j2 - b1*g2*h2 + 3*b1*k2*n2 - 3*b1*l2*m2 - b2**2*p1 + 2*b2*c1*p2 - 4*b2*c2*p1 + b2*f1*j2 - 2*b2*f2*j1 - b2*g1*h2 + 2*b2*g2*h1 - 3*b2*k2*n1 + 3*b2*l2*m1 + 4*c1*c2*p2 - 4*c2**2*p1 + 3*c2*f1*j2 - 3*c2*f2*j1 - 3*c2*g1*h2 + 3*c2*g2*h1 + 3*c2*k1*n2 - 3*c2*k2*n1 - 3*c2*l1*m2 + 3*c2*l2*m1 + 2*d1*f2*n2 - 2*d1*g2*m2 - 2*d1*h2*l2 + 2*d1*j2*k2 - d2*f1*n2 - d2*f2*n1 + d2*g1*m2 + d2*g2*m1 + d2*h1*l2 + d2*h2*l1 - d2*j1*k2 - d2*j2*k1 + 2*e1*f2*m2 + 2*e1*g2*n2 - 2*e1*h2*k2 - 2*e1*j2*l2 - e2*f1*m2 - e2*f2*m1 - e2*g1*n2 - e2*g2*n1 + e2*h1*k2 + e2*h2*k1 + e2*j1*l2 + e2*j2*l1 + f1*f2*p2 - 3*f1*g2*o2 - f2**2*p1 + 3*f2*g1*o2 + g1*g2*p2 - g2**2*p1 + h1*h2*p2 + 3*h1*j2*o2 - h2**2*p1 - 3*h2*j1*o2 + j1*j2*p2 - j2**2*p1 + k1*k2*p2 - 3*k1*l2*o2 - k2**2*p1 + 3*k2*l1*o2 + l1*l2*p2 - l2**2*p1 + m1*m2*p2 + 3*m1*n2*o2 - m2**2*p1 - 3*m2*n1*o2 + n1*n2*p2 - n2**2*p1 + 4*o1*o2*p2 - 4*o2**2*p1
