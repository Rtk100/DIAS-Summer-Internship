# %%
from sympy import *
from sympy.physics.quantum.dagger import Dagger
from sympy import pprint
from sympy.vector import CoordSys3D

# %%
from IPython.display import display, Latex
init_printing(use_latex='mathjax') # sympy method

# %% [markdown]
# ##### Number of D6-Branes
#
# N

# %%
N = symbols("N")
N = 3
# Need an explicit number for N in order to use the .as_explicit() argument

# %% [markdown]
# Constants

# %%
g = symbols("g")
c1, c2, c3, c4 =symbols("c^1 c^2 c^3 c^4")
c12, c21, c13, c31, c14, c41 = symbols("c^{12} c^{21} c^{13} c^{31} c^{14} c^{41}")
c23, c32, c24, c42, c34, c43 = symbols("c^{23} c^{32} c^{24} c^{42} c^{34} c^{43}")

# %% [markdown]
# $X^i$, i = 1,2,3
#
# $\dot{X^i}$, i = 1,2,3

# %%
X1_1, X1_2, X1_3, X1_4, X1_5, X1_6, X1_7, X1_8, X1_9 = symbols("X_1^1 X_2^1 X_3^1 X_4^1 X_5^1 X_6^1 X_7^1 X_8^1 X_9^1")
X2_1, X2_2, X2_3, X2_4, X2_5, X2_6, X2_7, X2_8, X2_9 = symbols("X_1^2 X_2^2 X_3^2 X_4^2 X_5^2 X_6^2 X_7^2 X_8^2 X_9^2")
X3_1, X3_2, X3_3, X3_4, X3_5, X3_6, X3_7, X3_8, X3_9 = symbols("X_1^3 X_2^3 X_3^3 X_4^3 X_5^3 X_6^3 X_7^3 X_8^3 X_9^3")

X1_1_dot, X1_2_dot, X1_3_dot, X1_4_dot, X1_5_dot, X1_6_dot, X1_7_dot, X1_8_dot, X1_9_dot = symbols(r"\dot{X_1^1} \dot{X_2^1} \dot{X_3^1} \dot{X_4^1} \dot{X_5^1} \dot{X_6^1} \dot{X_7^1} \dot{X_8^1} \dot{X_9^1}")
X2_1_dot, X2_2_dot, X2_3_dot, X2_4_dot, X2_5_dot, X2_6_dot, X2_7_dot, X2_8_dot, X2_9_dot = symbols(r"\dot{X_1^2} \dot{X_2^2} \dot{X_3^2} \dot{X_4^2} \dot{X_5^2} \dot{X_6^2} \dot{X_7^2} \dot{X_8^2} \dot{X_9^2}")
X3_1_dot, X3_2_dot, X3_3_dot, X3_4_dot, X3_5_dot, X3_6_dot, X3_7_dot, X3_8_dot, X3_9_dot = symbols(r"\dot{X_1^3} \dot{X_2^3} \dot{X_3^3} \dot{X_4^3} \dot{X_5^3} \dot{X_6^3} \dot{X_7^3} \dot{X_8^3} \dot{X_9^3}")

# %% [markdown]
# $X^4$
#
# $\dot{X^4}$

# %%
X4_1_dot = MatrixSymbol("\dot{X_1^4}", N, N)
X4_2_dot = MatrixSymbol("\dot{X_2^4}", N, N)
X4_3_dot = MatrixSymbol("\dot{X_3^4}", N, N)
X4_4_dot = MatrixSymbol("\dot{X_4^4}", N, N)
X4_5_dot = MatrixSymbol("\dot{X_5^4}", N, N)
X4_6_dot = MatrixSymbol("\dot{X_6^4}", N, N)
X4_7_dot = MatrixSymbol("\dot{X_7^4}", N, N)
X4_8_dot = MatrixSymbol("\dot{X_8^4}", N, N)
X4_9_dot = MatrixSymbol("\dot{X_9^4}", N, N)

X4_1 = MatrixSymbol("X_1^4", N, N)
X4_2 = MatrixSymbol("X_2^4", N, N)
X4_3 = MatrixSymbol("X_3^4", N, N)
X4_4 = MatrixSymbol("X_4^4", N, N)
X4_5 = MatrixSymbol("X_5^4", N, N)
X4_6 = MatrixSymbol("X_6^4", N, N)
X4_7 = MatrixSymbol("X_7^4", N, N)
X4_8 = MatrixSymbol("X_8^4", N, N)
X4_9 = MatrixSymbol("X_9^4", N, N)

# %% [markdown]
# Z
#
# Need to add Z^4l as column vectors and Z^k4 as column vectors. They're both column vectors

# %%
Z12, Z13, Z21, Z23, Z31, Z32 = symbols(r"Z^{12} Z^{13} Z^{21} Z^{23} Z^{31} Z^{32}")

Z12_dot, Z13_dot, Z21_dot, Z23_dot = symbols(r"\dot{Z^{12}} \dot{Z^{13}} \dot{Z^{21}} \dot{Z^{23}}}")
Z31_dot, Z32_dot = symbols(r"\dot{Z^{31}} \dot{Z^{32}}}")

# %%
Z14 = MatrixSymbol("Z^{14}", 1, N)
Z24 = MatrixSymbol("Z^{24}", 1, N)
Z34 = MatrixSymbol("Z^{34}", 1, N)
Z41 = MatrixSymbol("Z^{41}", N, 1)
Z42 = MatrixSymbol("Z^{42}", N, 1)
Z43 = MatrixSymbol("Z^{43}", N, 1)

Z14_dot = MatrixSymbol("\dot{Z^{14}}", 1, N)
Z24_dot = MatrixSymbol("\dot{Z^{24}}", 1, N)
Z34_dot = MatrixSymbol("\dot{Z^{34}}", 1, N)
Z41_dot = MatrixSymbol("\dot{Z^{41}}", N, 1)
Z42_dot = MatrixSymbol("\dot{Z^{42}}", N, 1)
Z43_dot = MatrixSymbol("\dot{Z^{43}}", N, 1)

# %%
# Dagger() and .adjoint() are the same thing
print(Dagger(Z14) == Z14.adjoint()) 

# Showing that sympy interprets Dagger correctly: Z24 = column vector so Dagger(Z24) == row vector with conjugated elements:
Dagger(Z24).as_explicit() # Works as intended
# Out:
# True
# ⎡__________⎤
# ⎢Z_00__{24}⎥
# ⎢          ⎥
# ⎢__________⎥
# ⎢Z_01__{24}⎥
# ⎢          ⎥
# ⎢__________⎥
# ⎣Z_02__{24}⎦

# %%
# Row by column vector = scalar
(MatMul(Dagger(Z14),Z24)).as_explicit() # == Scalar
# Out:
# ⎡__________             __________             __________           ⎤
# ⎢Z_00__{14}⋅Z_00__{24}  Z_00__{14}⋅Z_01__{24}  Z_00__{14}⋅Z_02__{24}⎥
# ⎢                                                                   ⎥
# ⎢__________             __________             __________           ⎥
# ⎢Z_01__{14}⋅Z_00__{24}  Z_01__{14}⋅Z_01__{24}  Z_01__{14}⋅Z_02__{24}⎥
# ⎢                                                                   ⎥
# ⎢__________             __________             __________           ⎥
# ⎣Z_02__{14}⋅Z_00__{24}  Z_02__{14}⋅Z_01__{24}  Z_02__{14}⋅Z_02__{24}⎦

# %%
# Can add Symbol and MatrixSymbol together in 3 ways:
# 1. when MatrixSymbol is a scalar by indexing the list.
print((Dagger(Z14)*Z24)[0]+c1)

#2. when taking the trace of the scalar MatrixSymbol
print( Trace( (Dagger(Z14)*Z24) )+c1 )

#3. By defining a new scalar symbol with the same value as the scalar MatrixSymbol
temp = symbols("temp")
equation = Eq(temp,(Dagger(Z14)*Z24)[0] )
print(temp+c1)

# No errors produced
# Out:
# c^1 + conjugate(Z^{14}[0, 0])*Z^{24}[0, 0]
# c^1 + Trace(Adjoint(Z^{14})*Z^{24})
# c^1 + temp

# %%
# Testing if method 1. in the above cell breaks differentiation
deriverand = Trace( MatMul(Dagger(Z14),Z24) )+c1

deriverand.diff(Z14)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-57e1fa964a9a> in <module>
#       2 deriverand = Trace( MatMul(Dagger(Z14),Z24) )+c1
#       3
# ----> 4 deriverand.diff(Z14)
#       5
#
# ~\anaconda3\lib\site-packages\sympy\core\expr.py in diff(self, *symbols, **assumptions)
#    3500     def diff(self, *symbols, **assumptions):
#    3501         assumptions.setdefault("evaluate", True)
# -> 3502         return _derivative_dispatch(self, *symbols, **assumptions)
#    3503
#    3504     ###########################################################################
#
# ~\anaconda3\lib\site-packages\sympy\core\function.py in _derivative_dispatch(expr, *variables, **kwargs)
#    1944     if isinstance(expr, array_types) or any(isinstance(i[0], array_types) if isinstance(i, (tuple, list, Tuple)) else isinstance(i, array_types) for i in variables):
#    1945         from sympy.tensor.array.array_derivatives import ArrayDerivative
# -> 1946         return ArrayDerivative(expr, *variables, **kwargs)
#    1947     return Derivative(expr, *variables, **kwargs)
#    1948
#
# ~\anaconda3\lib\site-packages\sympy\tensor\array\array_derivatives.py in __new__(cls, expr, *variables, **kwargs)
#      15
#      16     def __new__(cls, expr, *variables, **kwargs):
# ---> 17         obj = super().__new__(cls, expr, *variables, **kwargs)
#      18         if isinstance(obj, ArrayDerivative):
#      19             obj._shape = obj._get_shape()
#
# ~\anaconda3\lib\site-packages\sympy\core\function.py in __new__(cls, expr, *variables, **kwargs)
#    1471                     expr *= old_v.diff(old_v)
#    1472
# -> 1473             obj = cls._dispatch_eval_derivative_n_times(expr, v, count)
#    1474             if obj is not None and obj.is_zero:
#    1475                 return obj
#
# ~\anaconda3\lib\site-packages\sympy\tensor\array\array_derivatives.py in _dispatch_eval_derivative_n_times(cls, expr, v, count)
#      92                 result = cls._call_derive_scalar_by_matrix(expr, v)
#      93             elif isinstance(v, MatrixExpr):
# ---> 94                 result = cls._call_derive_scalar_by_matexpr(expr, v)
#      95             elif isinstance(v, NDimArray):
#      96                 result = cls._call_derive_scalar_by_array(expr, v)
#
# ~\anaconda3\lib\site-packages\sympy\tensor\array\array_derivatives.py in _call_derive_scalar_by_matexpr(expr, v)
#      50     def _call_derive_scalar_by_matexpr(expr, v):  # type: (Expr, MatrixExpr) -> Expr
#      51         if expr.has(v):
# ---> 52             return _matrix_derivative(expr, v)
#      53         else:
#      54             return ZeroMatrix(*v.shape)
#
# ~\anaconda3\lib\site-packages\sympy\matrices\expressions\matexpr.py in _matrix_derivative(expr, x)
#     648 def _matrix_derivative(expr, x):
#     649     from sympy.tensor.array.array_derivatives import ArrayDerivative
# --> 650     lines = expr._eval_derivative_matrix_lines(x)
#     651
#     652     parts = [i.build() for i in lines]
#
# ~\anaconda3\lib\site-packages\sympy\core\expr.py in _eval_derivative_matrix_lines(self, x)
#    3873     def _eval_derivative_matrix_lines(self, x):
#    3874         from sympy.matrices.expressions.matexpr import _LeftRightArgs
# -> 3875         return [_LeftRightArgs([S.One, S.One], higher=self._eval_derivative(x))]
#    3876
#    3877
#
# ~\anaconda3\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError:
#      74                 retval = func(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sympy\core\add.py in _eval_derivative(self, s)
#     496     @cacheit
#     497     def _eval_derivative(self, s):
# --> 498         return self.func(*[a.diff(s) for a in self.args])
#     499
#     500     def _eval_nseries(self, x, n, logx, cdir=0):
#
# ~\anaconda3\lib\site-packages\sympy\core\add.py in <listcomp>(.0)
#     496     @cacheit
#     497     def _eval_derivative(self, s):
# --> 498         return self.func(*[a.diff(s) for a in self.args])
#     499
#     500     def _eval_nseries(self, x, n, logx, cdir=0):
#
# ~\anaconda3\lib\site-packages\sympy\core\expr.py in diff(self, *symbols, **assumptions)
#    3500     def diff(self, *symbols, **assumptions):
#    3501         assumptions.setdefault("evaluate", True)
# -> 3502         return _derivative_dispatch(self, *symbols, **assumptions)
#    3503
#    3504     ###########################################################################
#
# ~\anaconda3\lib\site-packages\sympy\core\function.py in _derivative_dispatch(expr, *variables, **kwargs)
#    1944     if isinstance(expr, array_types) or any(isinstance(i[0], array_types) if isinstance(i, (tuple, list, Tuple)) else isinstance(i, array_types) for i in variables):
#    1945         from sympy.tensor.array.array_derivatives import ArrayDerivative
# -> 1946         return ArrayDerivative(expr, *variables, **kwargs)
#    1947     return Derivative(expr, *variables, **kwargs)
#    1948
#
# ~\anaconda3\lib\site-packages\sympy\tensor\array\array_derivatives.py in __new__(cls, expr, *variables, **kwargs)
#      15
#      16     def __new__(cls, expr, *variables, **kwargs):
# ---> 17         obj = super().__new__(cls, expr, *variables, **kwargs)
#      18         if isinstance(obj, ArrayDerivative):
#      19             obj._shape = obj._get_shape()
#
# ~\anaconda3\lib\site-packages\sympy\core\function.py in __new__(cls, expr, *variables, **kwargs)
#    1471                     expr *= old_v.diff(old_v)
#    1472
# -> 1473             obj = cls._dispatch_eval_derivative_n_times(expr, v, count)
#    1474             if obj is not None and obj.is_zero:
#    1475                 return obj
#
# ~\anaconda3\lib\site-packages\sympy\tensor\array\array_derivatives.py in _dispatch_eval_derivative_n_times(cls, expr, v, count)
#      92                 result = cls._call_derive_scalar_by_matrix(expr, v)
#      93             elif isinstance(v, MatrixExpr):
# ---> 94                 result = cls._call_derive_scalar_by_matexpr(expr, v)
#      95             elif isinstance(v, NDimArray):
#      96                 result = cls._call_derive_scalar_by_array(expr, v)
#
# ~\anaconda3\lib\site-packages\sympy\tensor\array\array_derivatives.py in _call_derive_scalar_by_matexpr(expr, v)
#      50     def _call_derive_scalar_by_matexpr(expr, v):  # type: (Expr, MatrixExpr) -> Expr
#      51         if expr.has(v):
# ---> 52             return _matrix_derivative(expr, v)
#      53         else:
#      54             return ZeroMatrix(*v.shape)
#
# ~\anaconda3\lib\site-packages\sympy\matrices\expressions\matexpr.py in _matrix_derivative(expr, x)
#     648 def _matrix_derivative(expr, x):
#     649     from sympy.tensor.array.array_derivatives import ArrayDerivative
# --> 650     lines = expr._eval_derivative_matrix_lines(x)
#     651
#     652     parts = [i.build() for i in lines]
#
# ~\anaconda3\lib\site-packages\sympy\matrices\expressions\trace.py in _eval_derivative_matrix_lines(self, x)
#      55         from sympy.tensor.array.expressions.array_expressions import ArrayTensorProduct, ArrayContraction
#      56         from sympy.core.expr import ExprBuilder
# ---> 57         r = self.args[0]._eval_derivative_matrix_lines(x)
#      58         for lr in r:
#      59             if lr.higher == 1:
#
# ~\anaconda3\lib\site-packages\sympy\matrices\expressions\matmul.py in _eval_derivative_matrix_lines(self, x)
#     201                 left_rev = Identity(self.shape[0])
#     202
# --> 203             d = self.args[ind]._eval_derivative_matrix_lines(x)
#     204             for i in d:
#     205                 i.append_first(left_rev)
#
# ~\anaconda3\lib\site-packages\sympy\core\expr.py in _eval_derivative_matrix_lines(self, x)
#    3873     def _eval_derivative_matrix_lines(self, x):
#    3874         from sympy.matrices.expressions.matexpr import _LeftRightArgs
# -> 3875         return [_LeftRightArgs([S.One, S.One], higher=self._eval_derivative(x))]
#    3876
#    3877
#
# ~\anaconda3\lib\site-packages\sympy\matrices\expressions\matexpr.py in _eval_derivative(self, x)
#     218         if self.has(x):
#     219             # See if there are other methods using it:
# --> 220             return super()._eval_derivative(x)
#     221         else:
#     222             return ZeroMatrix(*self.shape)
#
# AttributeError: 'super' object has no attribute '_eval_derivative'

# %% [markdown]
# phi
#
# phi_dot

# %%
phi1_1 = 1/sqrt(2)*(X1_4+I*X1_5)
phi1_2 = 1/sqrt(2)*(X1_6+I*X1_7)
phi1_3 = 1/sqrt(2)*(X1_8+I*X1_9)

phi1_1_dag = 1/sqrt(2)*(X1_4-I*X1_5)
phi1_2_dag = 1/sqrt(2)*(X1_6-I*X1_7)
phi1_3_dag = 1/sqrt(2)*(X1_8-I*X1_9)

phi2_1 = 1/sqrt(2)*(X2_4+I*X2_5)
phi2_2 = 1/sqrt(2)*(X2_6+I*X2_7)
phi2_3 = 1/sqrt(2)*(X2_8+I*X2_9)

phi2_1_dag = 1/sqrt(2)*(X2_4-I*X2_5)
phi2_2_dag = 1/sqrt(2)*(X2_6-I*X2_7)
phi2_3_dag = 1/sqrt(2)*(X2_8-I*X2_9)

phi3_1 = 1/sqrt(2)*(X3_4+I*X3_5)
phi3_2 = 1/sqrt(2)*(X3_6+I*X3_7)
phi3_3 = 1/sqrt(2)*(X3_8+I*X3_9)

phi3_1_dag = 1/sqrt(2)*(X3_4-I*X3_5)
phi3_2_dag = 1/sqrt(2)*(X3_6-I*X3_7)
phi3_3_dag = 1/sqrt(2)*(X3_8-I*X3_9)

phi4_1 = 1/sqrt(2)*(X4_4+I*X4_5)
phi4_2 = 1/sqrt(2)*(X4_6+I*X4_7)
phi4_3 = 1/sqrt(2)*(X4_8+I*X4_9)

phi4_1_dag = 1/sqrt(2)*(X4_4-I*X4_5)
phi4_2_dag = 1/sqrt(2)*(X4_6-I*X4_7)
phi4_3_dag = 1/sqrt(2)*(X4_8-I*X4_9)

# %%
phi12 = phi1_3 - phi2_3
phi23 = phi2_1 - phi3_1
phi31 = phi3_2 - phi1_2

# %% [markdown]
# Y

# %%
Y1_11 = X1_1 * phi1_1
Y1_12 = X1_1 * phi1_2
Y1_13 = X1_1 * phi1_3
Y1_21 = X1_2 * phi1_1
Y1_22 = X1_2 * phi1_2
Y1_23 = X1_2 * phi1_3
Y1_31 = X1_3 * phi1_1
Y1_32 = X1_3 * phi1_2
Y1_33 = X1_3 * phi1_3

Y2_11 = X2_1 * phi2_1
Y2_12 = X2_1 * phi2_2
Y2_13 = X2_1 * phi2_3
Y2_21 = X2_2 * phi2_1
Y2_22 = X2_2 * phi2_2
Y2_23 = X2_2 * phi2_3
Y2_31 = X2_3 * phi2_1
Y2_32 = X2_3 * phi2_2
Y2_33 = X2_3 * phi2_3

Y3_11 = X3_1 * phi3_1
Y3_12 = X3_1 * phi3_2
Y3_13 = X3_1 * phi3_3
Y3_21 = X3_2 * phi3_1
Y3_22 = X3_2 * phi3_2
Y3_23 = X3_2 * phi3_3
Y3_31 = X3_3 * phi3_1
Y3_32 = X3_3 * phi3_2
Y3_33 = X3_3 * phi3_3

Y4_11 = MatMul( X4_1, phi4_1)
Y4_12 = MatMul( X4_1, phi4_2)
Y4_13 = MatMul( X4_1, phi4_3)
Y4_21 = MatMul( X4_2, phi4_1)
Y4_22 = MatMul( X4_2, phi4_2)
Y4_23 = MatMul( X4_2, phi4_3)
Y4_31 = MatMul( X4_3, phi4_1)
Y4_32 = MatMul( X4_3, phi4_2)
Y4_33 = MatMul( X4_3, phi4_3)

# %% [markdown]
# F

# %%
F12 = Z12*Z21 + c12/(g*g)
F21 = Z21*Z12 + c12/(g*g)
F23 = Z23*Z32 + c23/(g*g)
F32 = Z32*Z23 + c23/(g*g)
F13 = Z13*Z31 + c13/(g*g)
F31 = Z31*Z13 + c13/(g*g)

#F14 =  MatMul(Z14,Z41)[0] + c14*N/(g*g)
F14 = Trace( MatMul(Z14,Z41) ) + c14*N/(g*g)
F41 = MatMul(Z41,Z14) + c14*Identity(N)/(g*g) + (phi4_2*phi4_3 - phi4_3*phi4_2)
#F24 = MatMul(Z24,Z42)[0] + c24*N/(g*g)
F24 = Trace( MatMul(Z24,Z42) ) + c24*N/(g*g)
F42 = MatMul(Z42,Z24) + c24*Identity(N)/(g*g) + (phi4_3*phi4_1 - phi4_1*phi4_3)
#F34 = MatMul(Z34,Z43)[0] + c34*N/(g*g)
F34 = Trace( MatMul(Z34,Z43) ) + c34*N/(g*g)
F43 = MatMul(Z43,Z34) + c34*Identity(N)/(g*g) - (phi4_2*phi4_1 - phi4_1*phi4_2)

# %% [markdown]
# G

# %%
#G21 = phi12 * Z21 + Z23*Z31 + MatMul(Z24,Z41)[0]
#G12 = phi12 * Z12 + Z13*Z32 + MatMul(Z14,Z42)[0]

#G31 = phi31 * Z31 + Z32*Z21 - MatMul(Z34,Z41)[0]
#G13 = phi31 * Z13 + Z12*Z23 + MatMul(Z14,Z43)[0]

#G32 = phi23 * Z32 + Z31*Z12 + MatMul(Z34,Z42)[0]
#G23 = phi23 * Z23 + Z21*Z13 + MatMul(Z24,Z43)[0]

G21 = phi12 * Z21 + Z23*Z31 + Trace( MatMul(Z24,Z41) )
G12 = phi12 * Z12 + Z13*Z32 + Trace( MatMul(Z14,Z42) )

G31 = phi31 * Z31 + Z32*Z21 - Trace( MatMul(Z34,Z41) )
G13 = phi31 * Z13 + Z12*Z23 + Trace( MatMul(Z14,Z43) )

G32 = phi23 * Z32 + Z31*Z12 + Trace( MatMul(Z34,Z42) )
G23 = phi23 * Z23 + Z21*Z13 + Trace( MatMul(Z24,Z43) )

G41 = -phi4_1 * Z41 + Z42*Z21 + Z43*Z31
G14 = -Z14 * phi4_1 + Z12*Z24 - Z13*Z34

G42 = -phi4_2 * Z42 + Z43*Z32 + Z41*Z12
G24 = -Z24 * phi4_2 + Z21*Z14 + Z23*Z34

G43 = -phi4_3 * Z43 - Z41*Z13 + Z42*Z23
G34 = -Z34 * phi4_3 + Z31*Z14 + Z32*Z24

# %% [markdown]
# H

# %%
H12_1 = X1_1*Z12 - Z12*X2_1
H12_2 = X1_2*Z12 - Z12*X2_2
H12_3 = X1_3*Z12 - Z12*X2_3

H21_1 = X2_1*Z21 - Z21*X1_1
H21_2 = X2_2*Z21 - Z21*X1_2
H21_3 = X2_3*Z21 - Z21*X1_3

H13_1 = X1_1*Z13 - Z13*X3_1
H13_2 = X1_2*Z13 - Z13*X3_2
H13_3 = X1_3*Z13 - Z13*X3_3

H31_1 = X3_1*Z31 - Z31*X1_1
H31_2 = X3_2*Z31 - Z31*X1_2
H31_3 = X3_3*Z31 - Z31*X1_3

H14_1 = X1_1*Z14 - Z14*X4_1
H14_2 = X1_2*Z14 - Z14*X4_2
H14_3 = X1_3*Z14 - Z14*X4_3

H41_1 = X4_1*Z41 - Z41*X1_1
H41_2 = X4_2*Z41 - Z41*X1_2
H41_3 = X4_3*Z41 - Z41*X1_3

H32_1 = X3_1*Z32 - Z32*X2_1
H32_2 = X3_2*Z32 - Z32*X2_2
H32_3 = X3_3*Z32 - Z32*X2_3

H23_1 = X2_1*Z23 - Z23*X3_1
H23_2 = X2_2*Z23 - Z23*X3_2
H23_3 = X2_3*Z23 - Z23*X3_3

H34_1 = X3_1*Z34 - Z34*X4_1
H34_2 = X3_2*Z34 - Z34*X4_2
H34_3 = X3_3*Z34 - Z34*X4_3

H43_1 = X4_1*Z43 - Z43*X3_1
H43_2 = X4_2*Z43 - Z43*X3_2
H43_3 = X4_3*Z43 - Z43*X3_3

H24_1 = X2_1*Z24 - Z24*X4_1
H24_2 = X2_2*Z24 - Z24*X4_2
H24_3 = X2_3*Z24 - Z24*X4_3

H42_1 = X4_1*Z42 - Z42*X2_1
H42_2 = X4_2*Z42 - Z42*X2_2
H42_3 = X4_3*Z42 - Z42*X2_3

# %% [markdown]
# K

# %%
K1 = 1/2 * ( X1_1_dot**2+X1_2_dot**2+X1_3_dot**2+X1_4_dot**2+X1_5_dot**2+X1_6_dot**2+X1_7_dot**2+X1_8_dot**2+X1_9_dot**2 +
             X2_1_dot**2+X2_2_dot**2+X2_3_dot**2+X2_4_dot**2+X2_5_dot**2+X2_6_dot**2+X2_7_dot**2+X2_8_dot**2+X2_9_dot**2 +
             X3_1_dot**2+X3_2_dot**2+X3_3_dot**2+X3_4_dot**2+X3_5_dot**2+X3_6_dot**2+X3_7_dot**2+X3_8_dot**2+X3_9_dot**2 +
             Trace( MatMul(X4_1_dot, X4_1_dot) ) + Trace( MatMul(X4_2_dot, X4_2_dot) ) + Trace( MatMul(X4_3_dot, X4_3_dot) ) + 
             Trace( MatMul(X4_4_dot, X4_4_dot) ) + Trace( MatMul(X4_5_dot, X4_5_dot) ) + Trace( MatMul(X4_6_dot, X4_6_dot) ) + 
             Trace( MatMul(X4_7_dot, X4_7_dot) ) + Trace( MatMul(X4_8_dot, X4_8_dot) ) + Trace( MatMul(X4_9_dot, X4_9_dot) ) )

K2 = 1/2 * ( Dagger(Z12_dot)*Z12_dot + Dagger(Z13_dot)*Z13_dot + Trace(Dagger(Z14_dot)*Z14_dot) + Dagger(Z21_dot)*Z21_dot + 
             Dagger(Z23_dot)*Z23_dot + Trace(Dagger(Z24_dot)*Z24_dot) + Dagger(Z31_dot)*Z31_dot + Dagger(Z32_dot)*Z32_dot + 
             Trace(Dagger(Z34_dot)*Z34_dot) + Trace(Dagger(Z41_dot)*Z41_dot) + Trace(Dagger(Z42_dot)*Z42_dot) + 
             Trace(Dagger(Z43_dot)*Z43_dot) )

K = K1 + K2
K
# Out:
#                 2                   2                   2                   2
# 0.5⋅\dot{X_1__1}  + 0.5⋅\dot{X_1__2}  + 0.5⋅\dot{X_1__3}  + 0.5⋅\dot{X_2__1}
#
#                   2                   2                   2
# + 0.5⋅\dot{X_2__2}  + 0.5⋅\dot{X_2__3}  + 0.5⋅\dot{X_3__1}  + 0.5⋅\dot{X_3__2}
#
# 2                   2                   2                   2
#   + 0.5⋅\dot{X_3__3}  + 0.5⋅\dot{X_4__1}  + 0.5⋅\dot{X_4__2}  + 0.5⋅\dot{X_4__
#
#   2                   2                   2                   2
# 3}  + 0.5⋅\dot{X_5__1}  + 0.5⋅\dot{X_5__2}  + 0.5⋅\dot{X_5__3}  + 0.5⋅\dot{X_6
#
#     2                   2                   2                   2
# __1}  + 0.5⋅\dot{X_6__2}  + 0.5⋅\dot{X_6__3}  + 0.5⋅\dot{X_7__1}  + 0.5⋅\dot{X
#
#       2                   2                   2                   2
# _7__2}  + 0.5⋅\dot{X_7__3}  + 0.5⋅\dot{X_8__1}  + 0.5⋅\dot{X_8__2}  + 0.5⋅\dot
#
#         2                   2                   2                   2
# {X_8__3}  + 0.5⋅\dot{X_9__1}  + 0.5⋅\dot{X_9__2}  + 0.5⋅\dot{X_9__3}  + 0.5⋅\d
#
#                          †                                  †
# ot{Z__{12}}⋅\dot{Z__{12}}  + 0.5⋅\dot{Z__{13}}⋅\dot{Z__{13}}  + 0.5⋅\dot{Z__{2
#
#                  †                                    †
# 1}}⋅\dot{Z__{21}}  + 0.5⋅\dot{Z__{23}}}⋅\dot{Z__{23}}}  + 0.5⋅\dot{Z__{31}}⋅\d
#
#            †                                    †         ⎛             †
# ot{Z__{31}}  + 0.5⋅\dot{Z__{32}}}⋅\dot{Z__{32}}}  + 0.5⋅tr⎝\dot{Z__{14}} ⋅\dot
#
#          ⎞         ⎛             †              ⎞         ⎛             †
# {Z__{14}}⎠ + 0.5⋅tr⎝\dot{Z__{24}} ⋅\dot{Z__{24}}⎠ + 0.5⋅tr⎝\dot{Z__{34}} ⋅\dot
#
#          ⎞         ⎛             †              ⎞         ⎛             †
# {Z__{34}}⎠ + 0.5⋅tr⎝\dot{Z__{41}} ⋅\dot{Z__{41}}⎠ + 0.5⋅tr⎝\dot{Z__{42}} ⋅\dot
#
#          ⎞         ⎛             †              ⎞
# {Z__{42}}⎠ + 0.5⋅tr⎝\dot{Z__{43}} ⋅\dot{Z__{43}}⎠ + 0.5⋅tr(\dot{X_1__4}⋅\dot{X
#
#
# _1__4}) + 0.5⋅tr(\dot{X_2__4}⋅\dot{X_2__4}) + 0.5⋅tr(\dot{X_3__4}⋅\dot{X_3__4}
#
#
# ) + 0.5⋅tr(\dot{X_4__4}⋅\dot{X_4__4}) + 0.5⋅tr(\dot{X_5__4}⋅\dot{X_5__4}) + 0.
#
#
# 5⋅tr(\dot{X_6__4}⋅\dot{X_6__4}) + 0.5⋅tr(\dot{X_7__4}⋅\dot{X_7__4}) + 0.5⋅tr(\
#
#
# dot{X_8__4}⋅\dot{X_8__4}) + 0.5⋅tr(\dot{X_9__4}⋅\dot{X_9__4})

# %% [markdown]
# V

# %% [markdown]
# $Z^{14} Z^{24}^{\dagger}
# $

# %%
Trace((Dagger(F41) * F41))
# Out:
#   ⎛⎛       †
#   ⎜⎜c__{14}     †          †        †      ⎛      †      †⎞ ⎛      †      †⎞
#   ⎜⎜────────⋅(𝕀)  + Z__{14} ⋅Z__{41}  -1/2⋅⎝-ⅈ⋅X⁴₇  + X⁴₆ ⎠⋅⎝-ⅈ⋅X⁴₉  + X⁴₈ ⎠ +
# tr⎜⎜     2
#   ⎜⎜ ⎛ †⎞
#   ⎝⎝ ⎝g ⎠
#
#                                       ⎞
#      ⎛      †      †⎞ ⎛      †      †⎞⎟ ⎛c__{14}
#  1/2⋅⎝-ⅈ⋅X⁴₉  + X⁴₈ ⎠⋅⎝-ⅈ⋅X⁴₇  + X⁴₆ ⎠⎟⋅⎜───────⋅𝕀 + Z__{41}⋅Z__{14} -1/2⋅(ⅈ⋅X
#                                       ⎟ ⎜    2
#                                       ⎟ ⎝   g
#                                       ⎠
#
#                                                           ⎞
#                                                          ⎞⎟
# ⁴₉ + X⁴₈)⋅(ⅈ⋅X⁴₇ + X⁴₆) + 1/2⋅(ⅈ⋅X⁴₇ + X⁴₆)⋅(ⅈ⋅X⁴₉ + X⁴₈)⎟⎟
#                                                          ⎟⎟
#                                                          ⎠⎟
#                                                           ⎠

# %%
G41
# Out:
#                                   -√2
# Z__{21}⋅Z__{42} + Z__{31}⋅Z__{43} ────⋅(ⅈ⋅X⁴₅ + X⁴₄)⋅Z__{41}
#                                    2

# %%
V_gauge =      ( Dagger(H12_1)*H12_1 + Dagger(H12_2)*H12_2 + Dagger(H12_3)*H12_3 + 
                 Dagger(H21_1)*H21_1 + Dagger(H21_2)*H21_2 + Dagger(H21_3)*H21_3 + 
                 Dagger(H13_1)*H13_1 + Dagger(H13_2)*H13_2 + Dagger(H13_3)*H13_3 + 
                 Dagger(H31_1)*H31_1 + Dagger(H31_2)*H31_2 + Dagger(H31_3)*H31_3 + 
                 Dagger(H23_1)*H23_1 + Dagger(H23_2)*H23_2 + Dagger(H23_3)*H23_3 + 
                 Dagger(H32_1)*H32_1 + Dagger(H32_2)*H32_2 + Dagger(H32_3)*H32_3 + 
                 Trace ( Dagger(H14_1)*H14_1 ) + Trace ( Dagger(H14_2)*H14_2 ) + Trace ( Dagger(H14_3)*H14_3 ) + 
                 Trace ( Dagger(H41_1)*H41_1 ) + Trace ( Dagger(H41_2)*H41_2 ) + Trace ( Dagger(H41_3)*H41_3 ) + 
                 Trace ( Dagger(H24_1)*H24_1 ) + Trace ( Dagger(H24_2)*H24_2 ) + Trace ( Dagger(H24_3)*H24_3 ) + 
                 Trace ( Dagger(H42_1)*H42_1 ) + Trace ( Dagger(H42_2)*H42_2 ) + Trace ( Dagger(H42_3)*H42_3 ) + 
                 Trace ( Dagger(H34_1)*H34_1 ) + Trace ( Dagger(H34_2)*H34_2 ) + Trace ( Dagger(H34_3)*H34_3 ) + 
                 Trace ( Dagger(H43_1)*H43_1 ) + Trace ( Dagger(H43_2)*H43_2 ) + Trace ( Dagger(H43_3)*H43_3 ) +
                 
                 Trace( Y1 )
               )

V_D_argument = ( ( Z12 * Dagger(Z12) + Z13 * Dagger(Z13) + Trace(Z14 * Dagger(Z14)) + Z21 * Dagger(Z21) + 
                 Z23 * Dagger(Z23) + Trace(Z24 * Dagger(Z24)) + Z31 * Dagger(Z31) + Z32 * Dagger(Z32) + 
                 Trace(Z34 * Dagger(Z34)) + Trace(Z41 * Dagger(Z41)) + Trace(Z42 * Dagger(Z42)) + Trace(Z43 * Dagger(Z43)) ) - 
                 ( Dagger(Z12)*Z12 + Dagger(Z13)*Z13 + Trace(Dagger(Z14)*Z14) + Dagger(Z21)*Z21 + 
                 Dagger(Z23)*Z23 + Trace(Dagger(Z24)*Z24) + Dagger(Z31)*Z31 + Dagger(Z32)*Z32 + 
                 Trace(Dagger(Z34)*Z34) + Trace(Dagger(Z41)*Z41) + Trace(Dagger(Z42)*Z42) + Trace(Dagger(Z43)*Z43) ) + 
                 ( phi1_1*Dagger(phi1_1) - Dagger(phi1_1)*phi1_1 + phi1_2*Dagger(phi1_2) - Dagger(phi1_2)*phi1_2 + 
                   phi1_3*Dagger(phi1_3) - Dagger(phi1_3)*phi1_3 + phi2_1*Dagger(phi2_1) - Dagger(phi2_1)*phi2_1 + 
                   phi2_2*Dagger(phi2_2) - Dagger(phi2_2)*phi2_2 + phi2_3*Dagger(phi2_3) - Dagger(phi2_3)*phi2_3 + 
                   phi3_1*Dagger(phi3_1) - Dagger(phi3_1)*phi3_1 + phi3_2*Dagger(phi3_2) - Dagger(phi3_2)*phi3_2 + 
                   phi3_3*Dagger(phi3_3) - Dagger(phi3_3)*phi3_3 + Trace(phi4_1*Dagger(phi4_1) - Dagger(phi4_1)*phi4_1) + 
                   Trace(phi4_2*Dagger(phi4_2) - Dagger(phi4_2)*phi4_2) + Trace(phi4_3*Dagger(phi4_3) - Dagger(phi4_3)*phi4_3 )) +
                 -(c1 + c2 + c3)/(g*g) - Trace( (c4)/(g*g)*Identity(N) ) )

V_D = 1/2 * V_D_argument * V_D_argument

V_F = ( Abs(F12)*Abs(F12) + Abs(F21)*Abs(F21) + Abs(F13)*Abs(F13) + Abs(F31)*Abs(F31) + Abs(F32)*Abs(F32) + Abs(F23)*Abs(F23) +
        F14 * Dagger(F14) + F24 * Dagger(F24) + F34 * Dagger(F34) + 
        Trace( Dagger(F41) * F41 ) + Trace( Dagger(F42) * F42) + Trace( Dagger(F43) * F43 )+
       
        Abs(G12)*Abs(G12) + Abs(G21)*Abs(G21) + Abs(G13)*Abs(G13) + Abs(G31)*Abs(G31) + Abs(G32)*Abs(G32) + Abs(G23)*Abs(G23) + 
        Trace( Dagger(G41) * G41) + Trace( G14 * Dagger(G14) ) + Trace( Dagger(G42) * G42) + Trace( G24 * Dagger(G24) ) + 
        Trace( Dagger(G43) * G43) + Trace( G34 * Dagger(G34) )
        )

V = 1/2 * g*g*(V_gauge + V_D + V_F)
V
# Out:
#        ⎛
#        ⎜
#      2 ⎜                            ⎛   †        †      †        †⎞
# 0.5⋅g ⋅⎜(X¹₁⋅Z__{12} - X²₁⋅Z__{12})⋅⎝X¹₁ ⋅Z__{12}  - X²₁ ⋅Z__{12} ⎠ + (X¹₁⋅Z__
#        ⎜
#        ⎜
#        ⎝
#
#
#
#                     ⎛   †        †      †        †⎞
# {13} - X³₁⋅Z__{13})⋅⎝X¹₁ ⋅Z__{13}  - X³₁ ⋅Z__{13} ⎠ + (-X¹₁⋅Z__{21} + X²₁⋅Z__{
#
#
#
#
#
#
#      ⎛     †        †      †        †⎞                                ⎛     †
# 21})⋅⎝- X¹₁ ⋅Z__{21}  + X²₁ ⋅Z__{21} ⎠ + (-X¹₁⋅Z__{31} + X³₁⋅Z__{31})⋅⎝- X¹₁ ⋅
#
#
#
#
#
#
#        †      †        †⎞                               ⎛   †        †      †
# Z__{31}  + X³₁ ⋅Z__{31} ⎠ + (X²₁⋅Z__{23} - X³₁⋅Z__{23})⋅⎝X²₁ ⋅Z__{23}  - X³₁ ⋅
#
#
#
#
#
#
#        †⎞                                ⎛     †        †      †        †⎞
# Z__{23} ⎠ + (-X²₁⋅Z__{32} + X³₁⋅Z__{32})⋅⎝- X²₁ ⋅Z__{32}  + X³₁ ⋅Z__{32} ⎠ + (
#
#
#
#
#
#
#                            ⎛   †        †      †        †⎞
# X¹₂⋅Z__{12} - X²₂⋅Z__{12})⋅⎝X¹₂ ⋅Z__{12}  - X²₂ ⋅Z__{12} ⎠ + (X¹₂⋅Z__{13} - X³
#
#
#
#
#
#
#            ⎛   †        †      †        †⎞                                ⎛
# ₂⋅Z__{13})⋅⎝X¹₂ ⋅Z__{13}  - X³₂ ⋅Z__{13} ⎠ + (-X¹₂⋅Z__{21} + X²₂⋅Z__{21})⋅⎝- X
#
#
#
#
#
#
#   †        †      †        †⎞                                ⎛     †        †
# ¹₂ ⋅Z__{21}  + X²₂ ⋅Z__{21} ⎠ + (-X¹₂⋅Z__{31} + X³₂⋅Z__{31})⋅⎝- X¹₂ ⋅Z__{31}
#
#
#
#
#
#
#      †        †⎞                               ⎛   †        †      †        †⎞
# + X³₂ ⋅Z__{31} ⎠ + (X²₂⋅Z__{23} - X³₂⋅Z__{23})⋅⎝X²₂ ⋅Z__{23}  - X³₂ ⋅Z__{23} ⎠
#
#
#
#
#
#
#                                 ⎛     †        †      †        †⎞
#  + (-X²₂⋅Z__{32} + X³₂⋅Z__{32})⋅⎝- X²₂ ⋅Z__{32}  + X³₂ ⋅Z__{32} ⎠ + (X¹₃⋅Z__{1
#
#
#
#
#
#
#                   ⎛   †        †      †        †⎞
# 2} - X²₃⋅Z__{12})⋅⎝X¹₃ ⋅Z__{12}  - X²₃ ⋅Z__{12} ⎠ + (X¹₃⋅Z__{13} - X³₃⋅Z__{13}
#
#
#
#
#
#
#   ⎛   †        †      †        †⎞                                ⎛     †
# )⋅⎝X¹₃ ⋅Z__{13}  - X³₃ ⋅Z__{13} ⎠ + (-X¹₃⋅Z__{21} + X²₃⋅Z__{21})⋅⎝- X¹₃ ⋅Z__{2
#
#
#
#
#
#
#   †      †        †⎞                                ⎛     †        †      †
# 1}  + X²₃ ⋅Z__{21} ⎠ + (-X¹₃⋅Z__{31} + X³₃⋅Z__{31})⋅⎝- X¹₃ ⋅Z__{31}  + X³₃ ⋅Z_
#
#
#
#
#
#
#      †⎞                               ⎛   †        †      †        †⎞
# _{31} ⎠ + (X²₃⋅Z__{23} - X³₃⋅Z__{23})⋅⎝X²₃ ⋅Z__{23}  - X³₃ ⋅Z__{23} ⎠ + (-X²₃⋅
#
#
#
#
#
#
#                        ⎛     †        †      †        †⎞   ⎛3⋅c__{14}
# Z__{32} + X³₃⋅Z__{32})⋅⎝- X²₃ ⋅Z__{32}  + X³₃ ⋅Z__{32} ⎠ + ⎜───────── + tr(Z__
#                                                            ⎜     2
#                                                            ⎝    g
#
#
#
#                ⎛                               †⎞
#              ⎞ ⎜___________________   3⋅c__{14} ⎟   ⎛3⋅c__{24}
# {14}⋅Z__{41})⎟⋅⎜tr(Z__{14}⋅Z__{41}) + ──────────⎟ + ⎜───────── + tr(Z__{24}⋅Z_
#              ⎟ ⎜                            2   ⎟   ⎜     2
#              ⎠ ⎜                        ⎛ †⎞    ⎟   ⎝    g
#                ⎝                        ⎝g ⎠    ⎠
#
#
#         ⎛                               †⎞
#       ⎞ ⎜___________________   3⋅c__{24} ⎟   ⎛3⋅c__{34}                      ⎞
# _{42})⎟⋅⎜tr(Z__{24}⋅Z__{42}) + ──────────⎟ + ⎜───────── + tr(Z__{34}⋅Z__{43})⎟
#       ⎟ ⎜                            2   ⎟   ⎜     2                         ⎟
#       ⎠ ⎜                        ⎛ †⎞    ⎟   ⎝    g                          ⎠
#         ⎝                        ⎝g ⎠    ⎠
#
#
#  ⎛                               †⎞   ⎛    ⎛c⁴  ⎞
#  ⎜___________________   3⋅c__{34} ⎟   ⎜    ⎜──⋅𝕀⎟     ⎛       †        ⎞     ⎛
# ⋅⎜tr(Z__{34}⋅Z__{43}) + ──────────⎟ + ⎜- tr⎜ 2  ⎟ - tr⎝Z__{14} ⋅Z__{14}⎠ - tr⎝
#  ⎜                            2   ⎟   ⎜    ⎝g   ⎠
#  ⎜                        ⎛ †⎞    ⎟   ⎝
#  ⎝                        ⎝g ⎠    ⎠
#
#
#
#        †        ⎞     ⎛       †        ⎞     ⎛       †        ⎞     ⎛       †
# Z__{24} ⋅Z__{24}⎠ - tr⎝Z__{34} ⋅Z__{34}⎠ - tr⎝Z__{41} ⋅Z__{41}⎠ - tr⎝Z__{42} ⋅
#
#
#
#
#
#
#        ⎞     ⎛       †        ⎞     ⎛               †⎞     ⎛               †⎞
# Z__{42}⎠ - tr⎝Z__{43} ⋅Z__{43}⎠ + tr⎝Z__{14}⋅Z__{14} ⎠ + tr⎝Z__{24}⋅Z__{24} ⎠
#
#
#
#
#
#
#     ⎛               †⎞     ⎛               †⎞     ⎛               †⎞     ⎛
# + tr⎝Z__{34}⋅Z__{34} ⎠ + tr⎝Z__{41}⋅Z__{41} ⎠ + tr⎝Z__{42}⋅Z__{42} ⎠ + tr⎝Z__{
#
#
#
#
#
#
#            †⎞     ⎛     ⎛      †      †⎞                                   ⎛
# 43}⋅Z__{43} ⎠ + tr⎝-1/2⋅⎝-ⅈ⋅X⁴₅  + X⁴₄ ⎠⋅(ⅈ⋅X⁴₅ + X⁴₄) + 1/2⋅(ⅈ⋅X⁴₅ + X⁴₄)⋅⎝-ⅈ
#
#
#
#
#
#
#     †      †⎞⎞     ⎛     ⎛      †      †⎞                                   ⎛
# ⋅X⁴₅  + X⁴₄ ⎠⎠ + tr⎝-1/2⋅⎝-ⅈ⋅X⁴₇  + X⁴₆ ⎠⋅(ⅈ⋅X⁴₇ + X⁴₆) + 1/2⋅(ⅈ⋅X⁴₇ + X⁴₆)⋅⎝-
#
#
#
#
#
#
#      †      †⎞⎞     ⎛     ⎛      †      †⎞                                   ⎛
# ⅈ⋅X⁴₇  + X⁴₆ ⎠⎠ + tr⎝-1/2⋅⎝-ⅈ⋅X⁴₉  + X⁴₈ ⎠⋅(ⅈ⋅X⁴₉ + X⁴₈) + 1/2⋅(ⅈ⋅X⁴₉ + X⁴₈)⋅⎝
#
#
#
#
#
#                                 ⎞ ⎛        ⎛c⁴  ⎞
#       †      †⎞⎞   -c¹ - c² - c³⎟ ⎜        ⎜──⋅𝕀⎟         ⎛       †        ⎞
# -ⅈ⋅X⁴₉  + X⁴₈ ⎠⎠ + ─────────────⎟⋅⎜- 0.5⋅tr⎜ 2  ⎟ - 0.5⋅tr⎝Z__{14} ⋅Z__{14}⎠ -
#                           2     ⎟ ⎜        ⎝g   ⎠
#                          g      ⎠ ⎝
#
#
#
#
#        ⎛       †        ⎞         ⎛       †        ⎞         ⎛       †
#  0.5⋅tr⎝Z__{24} ⋅Z__{24}⎠ - 0.5⋅tr⎝Z__{34} ⋅Z__{34}⎠ - 0.5⋅tr⎝Z__{41} ⋅Z__{41}
#
#
#
#
#
#
# ⎞         ⎛       †        ⎞         ⎛       †        ⎞         ⎛
# ⎠ - 0.5⋅tr⎝Z__{42} ⋅Z__{42}⎠ - 0.5⋅tr⎝Z__{43} ⋅Z__{43}⎠ + 0.5⋅tr⎝Z__{14}⋅Z__{1
#
#
#
#
#
#
#   †⎞         ⎛               †⎞         ⎛               †⎞         ⎛
# 4} ⎠ + 0.5⋅tr⎝Z__{24}⋅Z__{24} ⎠ + 0.5⋅tr⎝Z__{34}⋅Z__{34} ⎠ + 0.5⋅tr⎝Z__{41}⋅Z_
#
#
#
#
#
#
#      †⎞         ⎛               †⎞         ⎛               †⎞         ⎛     ⎛
# _{41} ⎠ + 0.5⋅tr⎝Z__{42}⋅Z__{42} ⎠ + 0.5⋅tr⎝Z__{43}⋅Z__{43} ⎠ + 0.5⋅tr⎝-1/2⋅⎝-
#
#
#
#
#
#
#      †      †⎞                                   ⎛      †      †⎞⎞         ⎛
# ⅈ⋅X⁴₅  + X⁴₄ ⎠⋅(ⅈ⋅X⁴₅ + X⁴₄) + 1/2⋅(ⅈ⋅X⁴₅ + X⁴₄)⋅⎝-ⅈ⋅X⁴₅  + X⁴₄ ⎠⎠ + 0.5⋅tr⎝-1
#
#
#
#
#
#
#    ⎛      †      †⎞                                   ⎛      †      †⎞⎞
# /2⋅⎝-ⅈ⋅X⁴₇  + X⁴₆ ⎠⋅(ⅈ⋅X⁴₇ + X⁴₆) + 1/2⋅(ⅈ⋅X⁴₇ + X⁴₆)⋅⎝-ⅈ⋅X⁴₇  + X⁴₆ ⎠⎠ + 0.5⋅
#
#
#
#
#
#
#   ⎛     ⎛      †      †⎞                                   ⎛      †      †⎞⎞
# tr⎝-1/2⋅⎝-ⅈ⋅X⁴₉  + X⁴₈ ⎠⋅(ⅈ⋅X⁴₉ + X⁴₈) + 1/2⋅(ⅈ⋅X⁴₉ + X⁴₈)⋅⎝-ⅈ⋅X⁴₉  + X⁴₈ ⎠⎠ +
#
#
#
#
#
#                     ⎞                                2
#  0.5⋅(-c¹ - c² - c³)⎟     │                  c__{12}│      │
#  ───────────────────⎟ + 2⋅│Z__{12}⋅Z__{21} + ───────│  + 2⋅│Z__{13}⋅Z__{31} +
#            2        ⎟     │                      2  │      │
#           g         ⎠     │                     g   │      │
#
#
#
#         2                                2
# c__{13}│      │                  c__{23}│    │                          ⎛  √2⋅
# ───────│  + 2⋅│Z__{23}⋅Z__{32} + ───────│  + │Z__{12}⋅Z__{23} + Z__{13}⋅⎜- ───
#     2  │      │                      2  │    │                          ⎝
#    g   │      │                     g   │
#
#
#
#                                                         2
# (X¹₆ + ⅈ⋅X¹₇)   √2⋅(X³₆ + ⅈ⋅X³₇)⎞                      │    │
# ───────────── + ────────────────⎟ + tr(Z__{14}⋅Z__{43})│  + │Z__{12}⋅Z__{31} +
#     2                  2        ⎠                      │    │
#
#
#
#
#                                                                      2
#          ⎛√2⋅(X²₄ + ⅈ⋅X²₅)   √2⋅(X³₄ + ⅈ⋅X³₅)⎞                      │    │
#  Z__{32}⋅⎜──────────────── - ────────────────⎟ + tr(Z__{34}⋅Z__{42})│  + │Z__{
#          ⎝       2                  2        ⎠                      │    │
#
#
#
#
#
#     ⎛√2⋅(X¹₈ + ⅈ⋅X¹₉)   √2⋅(X²₈ + ⅈ⋅X²₉)⎞
# 12}⋅⎜──────────────── - ────────────────⎟ + Z__{13}⋅Z__{32} + tr(Z__{14}⋅Z__{4
#     ⎝       2                  2        ⎠
#
#
#
#
#     2
#    │    │                          ⎛√2⋅(X²₄ + ⅈ⋅X²₅)   √2⋅(X³₄ + ⅈ⋅X³₅)⎞
# 2})│  + │Z__{13}⋅Z__{21} + Z__{23}⋅⎜──────────────── - ────────────────⎟ + tr(
#    │    │                          ⎝       2                  2        ⎠
#
#
#
#
#                  2
#                 │    │                          ⎛  √2⋅(X¹₆ + ⅈ⋅X¹₇)   √2⋅(X³₆
# Z__{24}⋅Z__{43})│  + │Z__{21}⋅Z__{32} + Z__{31}⋅⎜- ──────────────── + ────────
#                 │    │                          ⎝         2                  2
#
#
#
#
#                                 2
# + ⅈ⋅X³₇)⎞                      │    │        ⎛√2⋅(X¹₈ + ⅈ⋅X¹₉)   √2⋅(X²₈ + ⅈ⋅X
# ────────⎟ - tr(Z__{34}⋅Z__{41})│  + │Z__{21}⋅⎜──────────────── - ─────────────
#         ⎠                      │    │        ⎝       2                  2
#
#
#
#
#                                              2
# ²₉)⎞                                        │      ⎛⎛    †        †          †
# ───⎟ + Z__{23}⋅Z__{31} + tr(Z__{24}⋅Z__{41})│  + tr⎝⎝-X¹₁ ⋅Z__{41}  + Z__{41}
#    ⎠                                        │
#
#
#
#
#
#     †⎞                             ⎞     ⎛⎛   †        †     †        †⎞
# ⋅X⁴₁ ⎠⋅(-X¹₁⋅Z__{41} + X⁴₁⋅Z__{41})⎠ + tr⎝⎝X¹₁ ⋅Z__{14}  -X⁴₁ ⋅Z__{14} ⎠⋅(X¹₁⋅
#
#
#
#
#
#
#                      ⎞     ⎛⎛    †        †          †    †⎞
# Z__{14} -Z__{14}⋅X⁴₁)⎠ + tr⎝⎝-X²₁ ⋅Z__{42}  + Z__{42} ⋅X⁴₁ ⎠⋅(-X²₁⋅Z__{42} + X
#
#
#
#
#
#
#            ⎞     ⎛⎛   †        †     †        †⎞                           ⎞
# ⁴₁⋅Z__{42})⎠ + tr⎝⎝X²₁ ⋅Z__{24}  -X⁴₁ ⋅Z__{24} ⎠⋅(X²₁⋅Z__{24} -Z__{24}⋅X⁴₁)⎠ +
#
#
#
#
#
#
#    ⎛⎛    †        †          †    †⎞                             ⎞     ⎛⎛   †
#  tr⎝⎝-X³₁ ⋅Z__{43}  + Z__{43} ⋅X⁴₁ ⎠⋅(-X³₁⋅Z__{43} + X⁴₁⋅Z__{43})⎠ + tr⎝⎝X³₁ ⋅
#
#
#
#
#
#
#        †     †        †⎞                           ⎞     ⎛⎛    †        †
# Z__{34}  -X⁴₁ ⋅Z__{34} ⎠⋅(X³₁⋅Z__{34} -Z__{34}⋅X⁴₁)⎠ + tr⎝⎝-X¹₂ ⋅Z__{41}  + Z_
#
#
#
#
#
#
#      †    †⎞                             ⎞     ⎛⎛   †        †     †        †⎞
# _{41} ⋅X⁴₂ ⎠⋅(-X¹₂⋅Z__{41} + X⁴₂⋅Z__{41})⎠ + tr⎝⎝X¹₂ ⋅Z__{14}  -X⁴₂ ⋅Z__{14} ⎠
#
#
#
#
#
#
#                            ⎞     ⎛⎛    †        †          †    †⎞
# ⋅(X¹₂⋅Z__{14} -Z__{14}⋅X⁴₂)⎠ + tr⎝⎝-X²₂ ⋅Z__{42}  + Z__{42} ⋅X⁴₂ ⎠⋅(-X²₂⋅Z__{4
#
#
#
#
#
#
#                  ⎞     ⎛⎛   †        †     †        †⎞
# 2} + X⁴₂⋅Z__{42})⎠ + tr⎝⎝X²₂ ⋅Z__{24}  -X⁴₂ ⋅Z__{24} ⎠⋅(X²₂⋅Z__{24} -Z__{24}⋅X
#
#
#
#
#
#
#    ⎞     ⎛⎛    †        †          †    †⎞                             ⎞     ⎛
# ⁴₂)⎠ + tr⎝⎝-X³₂ ⋅Z__{43}  + Z__{43} ⋅X⁴₂ ⎠⋅(-X³₂⋅Z__{43} + X⁴₂⋅Z__{43})⎠ + tr⎝
#
#
#
#
#
#
# ⎛   †        †     †        †⎞                           ⎞     ⎛⎛    †
# ⎝X³₂ ⋅Z__{34}  -X⁴₂ ⋅Z__{34} ⎠⋅(X³₂⋅Z__{34} -Z__{34}⋅X⁴₂)⎠ + tr⎝⎝-X¹₃ ⋅Z__{41}
#
#
#
#
#
#
# †          †    †⎞                             ⎞     ⎛⎛   †        †     †
#   + Z__{41} ⋅X⁴₃ ⎠⋅(-X¹₃⋅Z__{41} + X⁴₃⋅Z__{41})⎠ + tr⎝⎝X¹₃ ⋅Z__{14}  -X⁴₃ ⋅Z__
#
#
#
#
#
#
#     †⎞                           ⎞     ⎛⎛    †        †          †    †⎞
# {14} ⎠⋅(X¹₃⋅Z__{14} -Z__{14}⋅X⁴₃)⎠ + tr⎝⎝-X²₃ ⋅Z__{42}  + Z__{42} ⋅X⁴₃ ⎠⋅(-X²₃
#
#
#
#
#
#
#                        ⎞     ⎛⎛   †        †     †        †⎞
# ⋅Z__{42} + X⁴₃⋅Z__{42})⎠ + tr⎝⎝X²₃ ⋅Z__{24}  -X⁴₃ ⋅Z__{24} ⎠⋅(X²₃⋅Z__{24} -Z__
#
#
#
#
#
#
#          ⎞     ⎛⎛    †        †          †    †⎞                             ⎞
# {24}⋅X⁴₃)⎠ + tr⎝⎝-X³₃ ⋅Z__{43}  + Z__{43} ⋅X⁴₃ ⎠⋅(-X³₃⋅Z__{43} + X⁴₃⋅Z__{43})⎠
#
#
#
#
#
#
#      ⎛⎛   †        †     †        †⎞                           ⎞     ⎛⎛
#  + tr⎝⎝X³₃ ⋅Z__{34}  -X⁴₃ ⋅Z__{34} ⎠⋅(X³₃⋅Z__{34} -Z__{34}⋅X⁴₃)⎠ + tr⎜⎜Z__{12}
#                                                                      ⎝⎝
#
#
#
#
#
#                           -√2                       ⎞ ⎛       †        †
# ⋅Z__{24} -Z__{13}⋅Z__{34} ────⋅Z__{14}⋅(ⅈ⋅X⁴₅ + X⁴₄)⎟⋅⎜Z__{12} ⋅Z__{24}  -Z__{
#                            2                        ⎠ ⎝
#
#
#
#
#
#    †        † -√2  ⎛      †      †⎞        †⎞⎞     ⎛⎛
# 13} ⋅Z__{34}  ────⋅⎝-ⅈ⋅X⁴₅  + X⁴₄ ⎠⋅Z__{14} ⎟⎟ + tr⎜⎜Z__{21}⋅Z__{14} + Z__{23}
#                2                            ⎠⎠     ⎝⎝
#
#
#
#
#
#          -√2                       ⎞ ⎛       †        †          †        † -√
# ⋅Z__{34} ────⋅Z__{24}⋅(ⅈ⋅X⁴₇ + X⁴₆)⎟⋅⎜Z__{21} ⋅Z__{14}  + Z__{23} ⋅Z__{34}  ──
#           2                        ⎠ ⎝                                       2
#
#
#
#
#
# 2  ⎛      †      †⎞        †⎞⎞     ⎛⎛                                  -√2
# ──⋅⎝-ⅈ⋅X⁴₇  + X⁴₆ ⎠⋅Z__{24} ⎟⎟ + tr⎜⎜Z__{31}⋅Z__{14} + Z__{32}⋅Z__{24} ────⋅Z_
#                             ⎠⎠     ⎝⎝                                   2
#
#
#
#
#
#                    ⎞ ⎛       †        †          †        † -√2  ⎛      †
# _{34}⋅(ⅈ⋅X⁴₉ + X⁴₈)⎟⋅⎜Z__{31} ⋅Z__{14}  + Z__{32} ⋅Z__{24}  ────⋅⎝-ⅈ⋅X⁴₉  + X⁴
#                    ⎠ ⎝                                       2
#
#
#
#
#
#  †⎞        †⎞⎞     ⎛⎛       †        †          †        † -√2         † ⎛
# ₈ ⎠⋅Z__{34} ⎟⎟ + tr⎜⎜Z__{12} ⋅Z__{41}  + Z__{32} ⋅Z__{43}  ────⋅Z__{42} ⋅⎝-ⅈ⋅X
#             ⎠⎠     ⎝⎝                                       2
#
#
#
#
#
#   †      †⎞⎞ ⎛                                  -√2                       ⎞⎞
# ⁴₇  + X⁴₆ ⎠⎟⋅⎜Z__{12}⋅Z__{41} + Z__{32}⋅Z__{43} ────⋅(ⅈ⋅X⁴₇ + X⁴₆)⋅Z__{42}⎟⎟ +
#            ⎠ ⎝                                   2                        ⎠⎠
#
#
#
#
#
#    ⎛⎛        †        †          †        † -√2         † ⎛      †      †⎞⎞ ⎛
#  tr⎜⎜-Z__{13} ⋅Z__{41}  + Z__{23} ⋅Z__{42}  ────⋅Z__{43} ⋅⎝-ⅈ⋅X⁴₉  + X⁴₈ ⎠⎟⋅⎜-
#    ⎝⎝                                        2                            ⎠ ⎝
#
#
#
#
#
#                                   -√2                       ⎞⎞     ⎛⎛       †
# Z__{13}⋅Z__{41} + Z__{23}⋅Z__{42} ────⋅(ⅈ⋅X⁴₉ + X⁴₈)⋅Z__{43}⎟⎟ + tr⎜⎜Z__{21} ⋅
#                                    2                        ⎠⎠     ⎝⎝
#
#
#
#
#
#        †          †        † -√2         † ⎛      †      †⎞⎞ ⎛
# Z__{42}  + Z__{31} ⋅Z__{43}  ────⋅Z__{41} ⋅⎝-ⅈ⋅X⁴₅  + X⁴₄ ⎠⎟⋅⎜Z__{21}⋅Z__{42}
#                               2                            ⎠ ⎝
#
#
#
#                                                    ⎛⎛       †
#                                                    ⎜⎜c__{14}     †          †
#                   -√2                       ⎞⎞     ⎜⎜────────⋅(𝕀)  + Z__{14} ⋅
# + Z__{31}⋅Z__{43} ────⋅(ⅈ⋅X⁴₅ + X⁴₄)⋅Z__{41}⎟⎟ + tr⎜⎜     2
#                    2                        ⎠⎠     ⎜⎜ ⎛ †⎞
#                                                    ⎝⎝ ⎝g ⎠
#
#
#
#        †      ⎛      †      †⎞ ⎛      †      †⎞       ⎛      †      †⎞ ⎛
# Z__{41}  -1/2⋅⎝-ⅈ⋅X⁴₇  + X⁴₆ ⎠⋅⎝-ⅈ⋅X⁴₉  + X⁴₈ ⎠ + 1/2⋅⎝-ⅈ⋅X⁴₉  + X⁴₈ ⎠⋅⎝-ⅈ⋅X⁴₇
#
#
#
#
#
#          ⎞
# †      †⎞⎟ ⎛c__{14}
#   + X⁴₆ ⎠⎟⋅⎜───────⋅𝕀 + Z__{41}⋅Z__{14} -1/2⋅(ⅈ⋅X⁴₉ + X⁴₈)⋅(ⅈ⋅X⁴₇ + X⁴₆) + 1/2
#          ⎟ ⎜    2
#          ⎟ ⎝   g
#          ⎠
#
#
#                              ⎞     ⎛⎛       †
#                             ⎞⎟     ⎜⎜c__{24}     †          †        †      ⎛
# ⋅(ⅈ⋅X⁴₇ + X⁴₆)⋅(ⅈ⋅X⁴₉ + X⁴₈)⎟⎟     ⎜⎜────────⋅(𝕀)  + Z__{24} ⋅Z__{42}  -1/2⋅⎝-
#                             ⎟⎟ + tr⎜⎜     2
#                             ⎠⎟     ⎜⎜ ⎛ †⎞
#                              ⎠     ⎝⎝ ⎝g ⎠
#
#
#                                                                        ⎞
#      †      †⎞ ⎛      †      †⎞       ⎛      †      †⎞ ⎛      †      †⎞⎟ ⎛c__{
# ⅈ⋅X⁴₉  + X⁴₈ ⎠⋅⎝-ⅈ⋅X⁴₅  + X⁴₄ ⎠ + 1/2⋅⎝-ⅈ⋅X⁴₅  + X⁴₄ ⎠⋅⎝-ⅈ⋅X⁴₉  + X⁴₈ ⎠⎟⋅⎜────
#                                                                        ⎟ ⎜
#                                                                        ⎟ ⎝   g
#                                                                        ⎠
#
#
#
# 24}
# ───⋅𝕀 + Z__{42}⋅Z__{24} -1/2⋅(ⅈ⋅X⁴₅ + X⁴₄)⋅(ⅈ⋅X⁴₉ + X⁴₈) + 1/2⋅(ⅈ⋅X⁴₉ + X⁴₈)⋅(
# 2
#
#
#
#
#              ⎞     ⎛⎛       †
#             ⎞⎟     ⎜⎜c__{34}     †          †        †      ⎛      †      †⎞ ⎛
# ⅈ⋅X⁴₅ + X⁴₄)⎟⎟     ⎜⎜────────⋅(𝕀)  + Z__{34} ⋅Z__{43}  -1/2⋅⎝-ⅈ⋅X⁴₅  + X⁴₄ ⎠⋅⎝
#             ⎟⎟ + tr⎜⎜     2
#             ⎠⎟     ⎜⎜ ⎛ †⎞
#              ⎠     ⎝⎝ ⎝g ⎠
#
#
#                                                        ⎞
#       †      †⎞       ⎛      †      †⎞ ⎛      †      †⎞⎟ ⎛c__{34}
# -ⅈ⋅X⁴₇  + X⁴₆ ⎠ + 1/2⋅⎝-ⅈ⋅X⁴₇  + X⁴₆ ⎠⋅⎝-ⅈ⋅X⁴₅  + X⁴₄ ⎠⎟⋅⎜───────⋅𝕀 + Z__{43}⋅
#                                                        ⎟ ⎜    2
#                                                        ⎟ ⎝   g
#                                                        ⎠
#
#
#                                                                            ⎞⎞
#                                                                           ⎞⎟⎟
# Z__{34} -1/2⋅(ⅈ⋅X⁴₇ + X⁴₆)⋅(ⅈ⋅X⁴₅ + X⁴₄) + 1/2⋅(ⅈ⋅X⁴₅ + X⁴₄)⋅(ⅈ⋅X⁴₇ + X⁴₆)⎟⎟⎟
#                                                                           ⎟⎟⎟
#                                                                           ⎠⎟⎟
#                                                                            ⎠⎟
#                                                                             ⎠

# %% [markdown]
# L

# %%
L = K - V

# %% [markdown]
# E.O.M for X

# %%
partial_L_partial_X1_dot = L.diff(X1_1_dot)
partial_L_partial_X1 = L.diff(X1_1)

partial_L_partial_X1_1_dot
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-274-855f4224e08b> in <module>
#       1 partial_L_partial_X1_dot = L.diff(X1_1_dot)
# ----> 2 partial_L_partial_X1 = L.diff(X1_1)
#       3
#       4 partial_L_partial_X1_1_dot
#
# ~\anaconda3\lib\site-packages\sympy\core\expr.py in diff(self, *symbols, **assumptions)
#    3500     def diff(self, *symbols, **assumptions):
#    3501         assumptions.setdefault("evaluate", True)
# -> 3502         return _derivative_dispatch(self, *symbols, **assumptions)
#    3503
#    3504     ###########################################################################
#
# ~\anaconda3\lib\site-packages\sympy\core\function.py in _derivative_dispatch(expr, *variables, **kwargs)
#    1945         from sympy.tensor.array.array_derivatives import ArrayDerivative
#    1946         return ArrayDerivative(expr, *variables, **kwargs)
# -> 1947     return Derivative(expr, *variables, **kwargs)
#    1948
#    1949
#
# ~\anaconda3\lib\site-packages\sympy\core\function.py in __new__(cls, expr, *variables, **kwargs)
#    1471                     expr *= old_v.diff(old_v)
#    1472
# -> 1473             obj = cls._dispatch_eval_derivative_n_times(expr, v, count)
#    1474             if obj is not None and obj.is_zero:
#    1475                 return obj
#
# ~\anaconda3\lib\site-packages\sympy\core\function.py in _dispatch_eval_derivative_n_times(cls, expr, v, count)
#    1934         # object, the default in `Basic` will call a loop over
#    1935         # `_eval_derivative`:
# -> 1936         return expr._eval_derivative_n_times(v, count)
#    1937
#    1938
#
# ~\anaconda3\lib\site-packages\sympy\core\basic.py in _eval_derivative_n_times(self, s, n)
#    1712             obj = self
#    1713             for i in range(n):
# -> 1714                 obj2 = obj._eval_derivative(s)
#    1715                 if obj == obj2 or obj2 is None:
#    1716                     break
#
# ~\anaconda3\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError:
#      74                 retval = func(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sympy\core\add.py in _eval_derivative(self, s)
#     496     @cacheit
#     497     def _eval_derivative(self, s):
# --> 498         return self.func(*[a.diff(s) for a in self.args])
#     499
#     500     def _eval_nseries(self, x, n, logx, cdir=0):
#
# ~\anaconda3\lib\site-packages\sympy\core\add.py in <listcomp>(.0)
#     496     @cacheit
#     497     def _eval_derivative(self, s):
# --> 498         return self.func(*[a.diff(s) for a in self.args])
#     499
#     500     def _eval_nseries(self, x, n, logx, cdir=0):
#
# ~\anaconda3\lib\site-packages\sympy\core\expr.py in diff(self, *symbols, **assumptions)
#    3500     def diff(self, *symbols, **assumptions):
#    3501         assumptions.setdefault("evaluate", True)
# -> 3502         return _derivative_dispatch(self, *symbols, **assumptions)
#    3503
#    3504     ###########################################################################
#
# ~\anaconda3\lib\site-packages\sympy\core\function.py in _derivative_dispatch(expr, *variables, **kwargs)
#    1945         from sympy.tensor.array.array_derivatives import ArrayDerivative
#    1946         return ArrayDerivative(expr, *variables, **kwargs)
# -> 1947     return Derivative(expr, *variables, **kwargs)
#    1948
#    1949
#
# ~\anaconda3\lib\site-packages\sympy\core\function.py in __new__(cls, expr, *variables, **kwargs)
#    1471                     expr *= old_v.diff(old_v)
#    1472
# -> 1473             obj = cls._dispatch_eval_derivative_n_times(expr, v, count)
#    1474             if obj is not None and obj.is_zero:
#    1475                 return obj
#
# ~\anaconda3\lib\site-packages\sympy\core\function.py in _dispatch_eval_derivative_n_times(cls, expr, v, count)
#    1934         # object, the default in `Basic` will call a loop over
#    1935         # `_eval_derivative`:
# -> 1936         return expr._eval_derivative_n_times(v, count)
#    1937
#    1938
#
# ~\anaconda3\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError:
#      74                 retval = func(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sympy\core\mul.py in _eval_derivative_n_times(self, s, n)
#     998             terms = []
#     999             for kvals, c in multinomial_coefficients_iterator(m, n):
# -> 1000                 p = prod([arg.diff((s, k)) for k, arg in zip(kvals, args)])
#    1001                 terms.append(c * p)
#    1002             return Add(*terms)
#
# ~\anaconda3\lib\site-packages\sympy\core\mul.py in <listcomp>(.0)
#     998             terms = []
#     999             for kvals, c in multinomial_coefficients_iterator(m, n):
# -> 1000                 p = prod([arg.diff((s, k)) for k, arg in zip(kvals, args)])
#    1001                 terms.append(c * p)
#    1002             return Add(*terms)
#
# ~\anaconda3\lib\site-packages\sympy\core\expr.py in diff(self, *symbols, **assumptions)
#    3500     def diff(self, *symbols, **assumptions):
#    3501         assumptions.setdefault("evaluate", True)
# -> 3502         return _derivative_dispatch(self, *symbols, **assumptions)
#    3503
#    3504     ###########################################################################
#
# ~\anaconda3\lib\site-packages\sympy\core\function.py in _derivative_dispatch(expr, *variables, **kwargs)
#    1945         from sympy.tensor.array.array_derivatives import ArrayDerivative
#    1946         return ArrayDerivative(expr, *variables, **kwargs)
# -> 1947     return Derivative(expr, *variables, **kwargs)
#    1948
#    1949
#
# ~\anaconda3\lib\site-packages\sympy\core\function.py in __new__(cls, expr, *variables, **kwargs)
#    1471                     expr *= old_v.diff(old_v)
#    1472
# -> 1473             obj = cls._dispatch_eval_derivative_n_times(expr, v, count)
#    1474             if obj is not None and obj.is_zero:
#    1475                 return obj
#
# ~\anaconda3\lib\site-packages\sympy\core\function.py in _dispatch_eval_derivative_n_times(cls, expr, v, count)
#    1934         # object, the default in `Basic` will call a loop over
#    1935         # `_eval_derivative`:
# -> 1936         return expr._eval_derivative_n_times(v, count)
#    1937
#    1938
#
# ~\anaconda3\lib\site-packages\sympy\core\basic.py in _eval_derivative_n_times(self, s, n)
#    1712             obj = self
#    1713             for i in range(n):
# -> 1714                 obj2 = obj._eval_derivative(s)
#    1715                 if obj == obj2 or obj2 is None:
#    1716                     break
#
# ~\anaconda3\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError:
#      74                 retval = func(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sympy\core\add.py in _eval_derivative(self, s)
#     496     @cacheit
#     497     def _eval_derivative(self, s):
# --> 498         return self.func(*[a.diff(s) for a in self.args])
#     499
#     500     def _eval_nseries(self, x, n, logx, cdir=0):
#
# ~\anaconda3\lib\site-packages\sympy\core\add.py in <listcomp>(.0)
#     496     @cacheit
#     497     def _eval_derivative(self, s):
# --> 498         return self.func(*[a.diff(s) for a in self.args])
#     499
#     500     def _eval_nseries(self, x, n, logx, cdir=0):
#
# ~\anaconda3\lib\site-packages\sympy\core\expr.py in diff(self, *symbols, **assumptions)
#    3500     def diff(self, *symbols, **assumptions):
#    3501         assumptions.setdefault("evaluate", True)
# -> 3502         return _derivative_dispatch(self, *symbols, **assumptions)
#    3503
#    3504     ###########################################################################
#
# ~\anaconda3\lib\site-packages\sympy\core\function.py in _derivative_dispatch(expr, *variables, **kwargs)
#    1945         from sympy.tensor.array.array_derivatives import ArrayDerivative
#    1946         return ArrayDerivative(expr, *variables, **kwargs)
# -> 1947     return Derivative(expr, *variables, **kwargs)
#    1948
#    1949
#
# ~\anaconda3\lib\site-packages\sympy\core\function.py in __new__(cls, expr, *variables, **kwargs)
#    1471                     expr *= old_v.diff(old_v)
#    1472
# -> 1473             obj = cls._dispatch_eval_derivative_n_times(expr, v, count)
#    1474             if obj is not None and obj.is_zero:
#    1475                 return obj
#
# ~\anaconda3\lib\site-packages\sympy\core\function.py in _dispatch_eval_derivative_n_times(cls, expr, v, count)
#    1934         # object, the default in `Basic` will call a loop over
#    1935         # `_eval_derivative`:
# -> 1936         return expr._eval_derivative_n_times(v, count)
#    1937
#    1938
#
# ~\anaconda3\lib\site-packages\sympy\core\basic.py in _eval_derivative_n_times(self, s, n)
#    1712             obj = self
#    1713             for i in range(n):
# -> 1714                 obj2 = obj._eval_derivative(s)
#    1715                 if obj == obj2 or obj2 is None:
#    1716                     break
#
# ~\anaconda3\lib\site-packages\sympy\matrices\expressions\trace.py in _eval_derivative(self, v)
#      49         if isinstance(expr, Trace):
#      50             # Avoid looping infinitely:
# ---> 51             raise NotImplementedError
#      52         return expr._eval_derivative(v)
#      53
#
# NotImplementedError:

# %%
from sympy.vector import Vector

# %%
vector
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-3b583b522e5a> in <module>
# ----> 1 vector
#
# NameError: name 'vector' is not defined
